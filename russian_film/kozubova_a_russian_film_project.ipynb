# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименование-столбцов" data-toc-modified-id="Переименование-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименование столбцов</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Изучение-столбцов-с-категориальными-переменными:-обработка-неявных-дубликатов" data-toc-modified-id="Изучение-столбцов-с-категориальными-переменными:-обработка-неявных-дубликатов-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Изучение столбцов с категориальными переменными: обработка неявных дубликатов</a></span><ul class="toc-item"><li><span><a href="#Изучение-столбца-'title'" data-toc-modified-id="Изучение-столбца-'title'-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Изучение столбца 'title'</a></span></li><li><span><a href="#Изучение-столбца-'type'" data-toc-modified-id="Изучение-столбца-'type'-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Изучение столбца 'type'</a></span></li><li><span><a href="#Изучение-столбца-'film_studio'" data-toc-modified-id="Изучение-столбца-'film_studio'-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Изучение столбца 'film_studio'</a></span></li><li><span><a href="#Изучение-столбца-'director'" data-toc-modified-id="Изучение-столбца-'director'-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Изучение столбца 'director'</a></span></li><li><span><a href="#Изучение-столбца-'producer'" data-toc-modified-id="Изучение-столбца-'producer'-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>Изучение столбца 'producer'</a></span></li><li><span><a href="#Изучение-столбцов-'age_restriction',-'financing_source'" data-toc-modified-id="Изучение-столбцов-'age_restriction',-'financing_source'-2.5.6"><span class="toc-item-num">2.5.6&nbsp;&nbsp;</span>Изучение столбцов 'age_restriction', 'financing_source'</a></span></li><li><span><a href="#Изучение-столбцов-'production_country',-'genres'" data-toc-modified-id="Изучение-столбцов-'production_country',-'genres'-2.5.7"><span class="toc-item-num">2.5.7&nbsp;&nbsp;</span>Изучение столбцов 'production_country', 'genres'</a></span></li></ul></li><li><span><a href="#Изучение-столбцов-с-количественными-переменными:-обработка-аномальных-значений" data-toc-modified-id="Изучение-столбцов-с-количественными-переменными:-обработка-аномальных-значений-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Изучение столбцов с количественными переменными: обработка аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Изучение-столбца-'refundable_support'" data-toc-modified-id="Изучение-столбца-'refundable_support'-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Изучение столбца 'refundable_support'</a></span></li><li><span><a href="#Изучение-столбца-'nonrefundable_support'" data-toc-modified-id="Изучение-столбца-'nonrefundable_support'-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Изучение столбца 'nonrefundable_support'</a></span></li><li><span><a href="#Изучение-столбца-'budget'" data-toc-modified-id="Изучение-столбца-'budget'-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>Изучение столбца 'budget'</a></span></li><li><span><a href="#Изучение-столбца-'box_office'" data-toc-modified-id="Изучение-столбца-'box_office'-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>Изучение столбца 'box_office'</a></span></li></ul></li><li><span><a href="#Категоризация-данных" data-toc-modified-id="Категоризация-данных-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Категоризация данных</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-взаимосвязи-между-годом-и-выходом-фильма-в-прокат" data-toc-modified-id="Анализ-взаимосвязи-между-годом-и-выходом-фильма-в-прокат-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ взаимосвязи между годом и выходом фильма в прокат</a></span></li><li><span><a href="#Анализ-изменения-динамики-проката-по-годам" data-toc-modified-id="Анализ-изменения-динамики-проката-по-годам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ изменения динамики проката по годам</a></span></li><li><span><a href="#Анализ-взаимосвязи-между-возрастным-ограничением-и-сборами-фильмов-в-прокате" data-toc-modified-id="Анализ-взаимосвязи-между-возрастным-ограничением-и-сборами-фильмов-в-прокате-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ взаимосвязи между возрастным ограничением и сборами фильмов в прокате</a></span></li><li><span><a href="#Исследование-фильмов-с-государственной-поддержкой" data-toc-modified-id="Исследование-фильмов-с-государственной-поддержкой-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Исследование фильмов с государственной поддержкой</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование данных о российском кинопрокате

# %% [markdown]
# **Цель исследования** — выявить текущие тренды на рынке российского кинопроката.
#
# **Для этого**:
#
# * Изучим фильмы, которые вышли в прокат в России.
# * Уделим внимание фильмам, которые получили государственную поддержку.
# * Исследуем, насколько такие фильмы интересны зрителю.
#
# **Описание данных**
#
# В этом исследовании будут использованы данные, опубликованные на [портале открытых данных Министерства культуры](https://opendata.mkrf.ru). Набор данных содержит: информацию о прокатных удостоверениях, сборах и государственной поддержке фильмов, информацию с сайта "КиноПоиск".
#
# Мы получим данные:
#
# * О прокатных удостоверениях из файла `mkrf_movies.csv`. У одного фильма может быть несколько прокатных удостоверений;
# * О прокате в российских кинотеатрах из файла `mkrf_shows.csv`.
#
# Датафрейм `mkrf_movies` содержит следующие данные:
#
# * `title` — название фильма
#
#
# * `puNumber` — номер прокатного удостоверения
#
#
# * `show_start_date` — дата премьеры фильма
#
#
# * `type` — тип фильма
#
#
# * `film_studio` — студия-производитель
#
#
# * `production_country` — страна-производитель
#
#
# * `director` — режиссёр
#
#
# * `producer` — продюссер
#
#
# * `age_restriction` — возрастная категория
#
#
# * `refundable_support` — объём возвратных средств государственной поддержки
#
#
# * `nonrefundable_support` — объём невозвратных средств государственной поддержки
#
#
# * `financing_source` — источник государственного финансирования
#
#
# * `budget` — общий бюджет фильма. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку
#
#
# * `ratings` — рейтинг фильма на КиноПоиске
#
#
# * `genres` — жанр фильма
#
#
# Таблица `mkrf_shows` содержит следующие столбцы:
#
# * `puNumber` — номер прокатного удостоверения
#
#
# * `box_office` — сборы в рублях
#
# **Ход исследования**
#
# Перед исследованием потребуется обзор данных, так как отсутствует информация об их качестве. Проверим данные на наличие ошибок и исправим самые критичные ошибки на этапе предобработки.
#
# Таким образом, исследование пройдёт в 3 этапа:
#
# 1. Обзор данных.
#
# Ознакомимся с содержанием, структурой и характеристиками данных. Посмотрим, какие потенциальные проблемы могут быть в данных.
#
# 2. Предобработка данных.
#
# Проведём более тщательную проверку на наличие ошибок и оценим их влияние.
#
# 3. Исследовательский анализ данных.
#
# Используя обработанные данные, проведём анализ и определим тренды на рынке российского кинопроката и насколько зрителю интересны фильмы, получившие государственную поддержку.

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# Откроем файлы с данными:

# %%
# импортируем библиотеку pandas
import pandas as pd

# %%
# сохраним в переменную ссылку на первый датафрейм - mkrf_movies
mkrf_movies = pd.read_csv('https://code.s3.yandex.net/datasets/mkrf_movies.csv')

# %%
# сохраним в переменную ссылку на втторой датафрейм - mkrf_shows в переменную
mkrf_shows = pd.read_csv('https://code.s3.yandex.net/datasets/mkrf_shows.csv')

# %% [markdown]
# Чтобы избежать ошибок при объединении двух датафреймов по значению столбца `puNumber`, убедимся, что в каждом из датафреймов этот столбец имеет одинаковый тип данных.
#
# Ознакомимся с общей информацией датафреймов:

# %%
# ознакомимся с общей информацией mkrf_movies
mkrf_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %%
# ознакомимся с общей информацией mkrf_shows
mkrf_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# В таблице `mkrf_movies` столбец `puNumber` принадлежит к типу данных **object**, в таблице `mkrf_shows` — к **int**. Приведём значения столбца в первом датафрейме к целочисленному типу:

# %%
# приведём значения столбца к int с помощью to_numeric() и astype()
# с помощью dropna() удалим значение NA, появившееся после применения to_numeric() и errors='coerce'
mkrf_movies['puNumber'] = pd.to_numeric(mkrf_movies['puNumber'], errors='coerce').dropna().astype(int)

# проверим результат
mkrf_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7485 non-null   float64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# Объединим таблицы `mkrf_movies` и `mkrf_shows`:

# %%
# объединим таблицы по совпадению значений столбца puNumber 
# с помощью параметра how='outer' объединим данные из внешней общей области
# сохраним результат в mkrf
mkrf = mkrf_movies.merge(mkrf_shows, on='puNumber', how='outer')

# выведем первые 20 строк новой таблицы и проверим результат
mkrf.head(20)
# Out:
#                                                 title     puNumber  \
# 0                                    Открытый простор  221048915.0
# 1                                Особо важное задание  111013716.0
# 2                                        Особо опасен  221038416.0
# 3                                        Особо опасен  221026916.0
# 4                                        Особо опасен  221030815.0
# 5                                   Остановился поезд  111013816.0
# 6                                     Любовь и голуби  111007013.0
# 7                                   Любовь и сигареты  221074614.0
# 8                                  Отпетые мошенники.  121011416.0
# 9                                 Отпуск за свой счет  111019114.0
# 10  Превосходство Борна /По одноименной новелле Ро...  221031416.0
# 11                                       Ответный ход  111019014.0
# 12  Малышка на миллион /По мотивам рассказов Ф.Х.Т...  221011415.0
# ...

# %% [markdown]
# Предварительно в таблице с данными можно заметить следующие проблемы:
#
# * Название столбца `puNumber` в **camelCase** вместо **snake_case**.
# * Вещественный тип данных в стообце `puNumber`. Обычно номер прокатного удостоверения — целое число.
# * Вещественный тип данных в столбце `box_office` со сборами в рублях. В этом исследовании понадобятся значения в рублях без копеек.
# * Пропущенные значения NaN в столбцах: `producer`, `refundable_support`, `nonrefundable_support`, `budget`, `financing_cource`, `box_office`. Пока неясно, какое влияние они могут оказать на результаты исследования.

# %% [markdown]
# Ознакомимся с общей информацией таблицы `mkrf`:

# %%
# выведем общую информацию о датафрейме
mkrf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7485 non-null   float64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# * Датафрейм содержит **16** столбцов и **7 486** строк.
# * В **11** столбцах есть пропущенные значения.
# * Заметен некорректный тип данных в столбце с датой премьеры фильма `show_start_date`. Следует преобразовать **строковый тип** к типу `datetime` для применения методов к датам и оптимизации памяти.
# * **Строковый тип** также найден в столбце `ratings`, с рейтингом фильма на КиноПоиске . Этот столбец содержит десятичные дроби, поэтому его следует привести к типу **float**.
# * Значения типа **float** видны в столбцах: c объёмом возвратных средств государственной поддержки `refundable_support`, объёмом невозвратных средств `nonrefundable_support`, общим бюджетом фильма `budget`, cборами в рублях `box_office`. В этом исследовании не понадобится дробная часть с копейками, поэтому нужно привести **вещественный тип** данных к **целочисленному**.

# %% [markdown]
# Посмотрим на распределение данных в столбцах с числами: `refundable_support`, `nonrefundable_support`, `budget` и `box_office`:

# %%
# импортируем библиотеку matplotlib для работы с графиками
import matplotlib.pyplot as plt

# %%
# построим гистограммы по выбранным столбцам
# увеличим количество корзин для большей детализации
# настроим размер графиков с помощью figsize
mkrf[['refundable_support', 'nonrefundable_support', 'budget', 'box_office']].hist(bins=50, figsize=(9,9))

# дадим общее название графикам
plt.suptitle('Распределение данных в столбцах с числами')

# выведем график на экран
plt.show()

# %% [markdown]
# * В столбцах `refundable_support` и `box_office` виден мощный узкий пик у отметки **0**. Вероятно, в данных есть большое количество нулевых значений или значений, приближенных к минимальному.
# * В некоторых столбцах видны отдельные, особенно крупные значения, похожие на выбросы: в `refundable_support` — более **150 000 000 ₽**, в `nonrefundable_support` — около **400 000 000 ₽**, в `budget` — более **2 000 000 000 ₽**.
# * На гистограмме по столбцу `nonrefundable_support` заметен длинный узкий хвост, выходящий за отметку в **100 000 000 ₽**.

# %% [markdown]
# Каждая гистограмма требует более детального рассмотрения. Для проверки данных на выбросы нужно построить диаграмму размаха для каждого столбца с числами и рассчитать межквартильный размах для наиболее точного результата.

# %% [markdown]
# **Выводы:**
#
# 1. Два датафрейма `mkrf_movies` и `mkrf_shows` объединили в одну таблицу — `mkrf`.
# 2. Таблица `mkrf` содержит **16** столбцов и **7 486** строк. Более половины столбцов содержит пропущенные значения.
# 3. Кроме пропусков, предварительно заметили следующие проблемы в данных: название столбца `puNumber` в camelCase вместо snake_case, некорректный тип данных в столбцах: `puNumber`, `show_start_date`, `ratings`, `refundable_support`, `nonrefundable_support`, `budget`, `box_office`.
# 4. Вероятно, в столбцах `refundable_support` и `box_office` есть **нулевые** или **близкие к нулю** значения. Возможно наличие выбросов в `refundable_support`, `nonrefundable_support`, `budget` и `box_office`.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Переименование столбцов

# %% [markdown]
# Проверим названия столбцов датафрейма `mkrf`:

# %%
# выведем список названий столбцов 
mkrf.columns
# Out:
# Index(['title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %% [markdown]
# В названии столбца `puNumber` заменим верблюжий регистр на змеиный:

# %%
# заменим исходное название с помощью метода rename()
mkrf = mkrf.rename(columns={'puNumber':'pu_number'})

# проверим результат
mkrf.columns
# Out:
# Index(['title', 'pu_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Приведём столбец `show_start_date` со строковым типом данных к типу `datetime`:

# %%
# преобразуем строку в datetime с помощью to_datetime()
mkrf['show_start_date'] = pd.to_datetime(
    mkrf['show_start_date'],
    format='%Y-%m-%dT%H:%M:%S'
)

# проверим результат
mkrf['show_start_date'].dtype
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# Преобразуем строковый тип данных в столбце `ratings` в `float`:

# %%
# заменим тип данных на float с помощью to_numeric()
# используем errors='coerce', чтобы избежать ошибок
mkrf['ratings'] = pd.to_numeric(mkrf['ratings'], errors='coerce')

# проверим результат
mkrf['ratings'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Приведём к целочисленному типу значения в столбцах `refundable_support`, `nonrefundable_support`, `budget`, `box_office`:

# %%
# сохраним в переменную столбцы, в которых значения — с нулевой дробной частью
columns_to_astype = ['refundable_support', 'nonrefundable_support', 'budget']

# переведём значения в Int64, так как он может хранить NaN 
mkrf[columns_to_astype] = mkrf[columns_to_astype].astype('Int64')

# округлим значения столбца box_office с ненулевой дробной частью и переведём в Int64
mkrf['box_office'] = mkrf['box_office'].round().astype('Int64')

# проверим результат
mkrf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   pu_number              7485 non-null   float64
#  2   show_start_date        7486 non-null   datetime64[ns, UTC]
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    Int64
#  10  nonrefundable_support  332 non-null    Int64
#  11  budget                 332 non-null    Int64
#  12  financing_source       332 non-null    object
#  13  ratings                6490 non-null   float64
# ...

# %% [markdown]
# Преобразуем столбец `pu_number` из вещественного в целочисленный тип данных:

# %%
# преобразуем тип в Int64, так как он может хранить NaN
mkrf['pu_number'] = mkrf['pu_number'].astype('Int64')

# проверим результат
mkrf['pu_number'].dtype
# Out:
# Int64Dtype()

# %% [markdown]
# ### Обработка пропущенных значений

# %% [markdown]
# Ещё раз ознакомимся с количеством пропущенных значений в каждом столбце датафрейма:

# %%
# выведем количество пропусков в каждом столбце по убыванию
mkrf.isna().sum().sort_values(ascending=False)
# Out:
# refundable_support       7154
# nonrefundable_support    7154
# budget                   7154
# financing_source         7154
# box_office               4328
# ratings                   996
# genres                    976
# producer                  568
# film_studio                18
# director                    9
# production_country          2
# pu_number                   1
# title                       0
# show_start_date             0
# type                        0
# age_restriction             0
# dtype: int64

# %% [markdown]
# Также посмотрим на доли пропусков по столбцам c числами:

# %%
# посмотрим на доли пропусков с помощью isna() и mean()
mkrf.isna().mean().sort_values(ascending=False)*100
# Out:
# refundable_support       95.565055
# nonrefundable_support    95.565055
# budget                   95.565055
# financing_source         95.565055
# box_office               57.814587
# ratings                  13.304836
# genres                   13.037670
# producer                  7.587497
# film_studio               0.240449
# director                  0.120224
# production_country        0.026717
# pu_number                 0.013358
# title                     0.000000
# show_start_date           0.000000
# type                      0.000000
# age_restriction           0.000000
# dtype: float64

# %% [markdown]
# * Больше всего пропусков в столбцах с денежными средствами в рублях: `refundable_support`, `nonrefundable_support` и `budget`  — **7154**, а также в `box_office` — **4328**.
# * Меньше всего пропущенных значений в столбцах: `director` — **9**, `production_country` — **2**, `pu_number` — **1**.
#
# Заполнение пропусков не требуется в некоторых столблцах, так как не все фильмы в таблице получили государственную поддержку. Например, если заполнить пропуски медианой в столбцах `refundable_support`, `nonrefundable_support`, `budget` это будет означать, что фильмы получили поддержку от государства в определённом размере и привести к некорректным результатам исследования.
#
# В столбце `box_office` со сборами в рублях слишком много пропущенных значений, почти половина — **4 328** из **7 486**. Заполнение пропусков медианой исказит результаты исследования. Нежелательно заполнение числом 0, которое может означать, что фильм не вышел в прокат.

# %% [markdown]
# Столбцы `genres`, `producer`, `film_studio`, `director` и `production_country`, `financing_source` содержат категориальные переменные. Пропуски в этих столбцах можно заполнить значением "неизвестно" для последующего выявления неявных дублей, более удобного анализа и восприятия:

# %%
# выберем нужные столбцы и сохраним их в переменную
category_columns_to_replace = ['genres', 'producer', 'film_studio', 'director', 'production_country', 'financing_source']

# заполним пропуски с помощью fillna()
mkrf[category_columns_to_replace] = mkrf[category_columns_to_replace].fillna('неизвестно')

# проверим результат
mkrf.isna().sum()
# Out:
# title                       0
# pu_number                   1
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# refundable_support       7154
# nonrefundable_support    7154
# budget                   7154
# financing_source            0
# ratings                   996
# genres                      0
# box_office               4328
# dtype: int64

# %% [markdown]
# Ознакомимся с информацией о фильме, у которого отсутствует номер прокатного удостоверения в столбце `pu_number`:

# %%
# отфильтруем строки с пропусками
mkrf[mkrf['pu_number'].isna()]
# Out:
#                                   title  pu_number           show_start_date  \
# 1797  Курбан-роман. (История с жертвой)       <NA> 2014-05-15 12:00:00+00:00
#
#                 type       film_studio production_country director  \
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                <NA>
#
#       nonrefundable_support  budget financing_source  ratings      genres  \
# 1797                   <NA>    <NA>       неизвестно      NaN  неизвестно
#
#       box_office
# 1797        <NA>

# %% [markdown]
# Данные об этом фильме выгрузились корректно, так как на [портале открытых данных Министерства культуры](https://opendata.mkrf.ru/) в разделе ["Реестр прокатных удостоверений фильмов"](https://opendata.mkrf.ru/opendata/7705851331-register_movies) действительно отсутсвует информация о номере прокатного удостоверения для фильма "Курбан-роман. (История с жертвой)" от 2014.05.15.
#
# Согласно информации на портале, этот фильм получил номер прокатного удостоверения позже — 2014.09.02. В названии фильма появилась точка - "Курбан-роман. (История с жертвой).".
#
# Выведем информацию о фильме в датафрейме `mkrf`:

# %%
# отфильтруем строки датафрейма
mkrf[mkrf['title'] == 'Курбан-роман. (История с жертвой).']
# Out:
#                                    title  pu_number           show_start_date  \
# 2078  Курбан-роман. (История с жертвой).  111009614 2014-09-02 12:00:00+00:00
#
#                 type       film_studio production_country director  \
# 2078  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 2078  М.Галицкая  «12+» - для детей старше 12 лет                <NA>
#
#       nonrefundable_support  budget financing_source  ratings      genres  \
# 2078                   <NA>    <NA>       неизвестно      NaN  неизвестно
#
#       box_office
# 2078           0

# %% [markdown]
# Номер удостоверения фильма — **111009614**, а премьера состоялась 2014.09.02. Сомнения вызывает значение **0** в столбце о сборах в рублях — `box_office`. Нулевое значение говорит о том, что фильм не вышел в прокат или была допущена ошибка при внесении данных в таблицу. Мы обработаем аномалии в этом столбце позже.
#
# Следует удалить строку с пропущенным значением в столбце `pu_number` из датафрейма, так как данные об этом фильме трудно назвать информативными из-за большого отсутствия пропусков в разных столбцах.

# %%
# удалим строку со значением NA и сохраним результат
mkrf = mkrf[mkrf['pu_number'].notna()]

# проверим результат
mkrf.isna().sum()
# Out:
# title                       0
# pu_number                   0
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# refundable_support       7153
# nonrefundable_support    7153
# budget                   7153
# financing_source            0
# ratings                   995
# genres                      0
# box_office               4327
# dtype: int64

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Проверим данные на наличие явных дубликатов:

# %%
# проверим таблицу на дубликаты с помощью duplicated()
mkrf.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В таблице отсутствуют явные дубликаты.

# %% [markdown]
# После преобразования к числовому типу данных, проверим столбец `'pu_number'` с номерами прокатного удостоверения на неявные дубликаты:

# %%
# выведем список уникальных значений с помощью unique()
print(sorted(mkrf['pu_number'].unique()))
# Out:
# [1811096, 111000110, 111000111, 111000112, 111000113, 111000114, 111000115, 111000116, 111000117, 111000118, 111000119, 111000210, 111000211, 111000212, 111000213, 111000214, 111000215, 111000216, 111000217, 111000218, 111000219, 111000310, 111000311, 111000312, 111000313, 111000314, 111000315, 111000317, 111000318, 111000319, 111000410, 111000411, 111000412, 111000413, 111000414, 111000415, 111000416, 111000417, 111000418, 111000419, 111000510, 111000511, 111000512, 111000513, 111000514, 111000515, 111000516, 111000517, 111000518, 111000519, 111000610, 111000611, 111000612, 111000613, 111000614, 111000615, 111000616, 111000617, 111000618, 111000619, 111000710, 111000711, 111000712, 111000714, 111000715, 111000716, 111000717, 111000718, 111000719, 111000810, 111000811, 111000812, 111000814, 111000815, 111000816, 111000818, 111000819, 111000910, 111000911, 111000912, 111000913, 111000914, 111000915, 111000916, 111000917, 111000918, 111000919, 111001010, 111001011, 111001012, 111001013
# ...

# %% [markdown]
# Значения в столбце выглядят достаточно упорядоченно. Неявные дубликаты отсутствуют.

# %% [markdown]
# ### Изучение столбцов с категориальными переменными: обработка неявных дубликатов

# %% [markdown]
# * Изучим уникальные значения столбцов с категориальными переменными: `title`, `type`, `film_studio`, `production_country`, `director`, `producer`, `age_restriction`, `financing_source`, `genres`.
# * Обработаем неявные дубликаты в столбцах.

# %% [markdown]
# #### Изучение столбца 'title'

# %% [markdown]
# Проверим список уникальных значений в столбце `title`:

# %%
# выведем список уникальных значений
sorted(mkrf['title'].unique())
# Out:
# [' Я ПРЕПОД',
#  '"SOS" над тайгой',
#  '"V" значит вендетта',
#  '"АРТиШОК" анимационный альманах авторских фильмов',
#  '"Бежин луг" Сергея Эйзенштейна',
#  '"Державная" Размышления 100 лет спустя',
#  '"Зеленое яблоко" анимационный альманах выпуск № 7',
#  '"Машины песенки". Серия "Опять Новый Год!"',
#  '"Море"',
#  '"Сезон дождей", "Диета Матроскина", "Шарик хочет телефон" из анимационного сериала "Простоквашино"',
#  '"Старый" Новый год',
#  '"Уорнер Бразерс Пикчерз" и "Леджендари Пикчерз": Тихоокеанский рубеж',
#  '"Фееринки". Серия "Фантик спешит на помощь"',
#  '"Хороший день", "Бог из машины/Deus EX", "Голод", "Психотроника", "Темная ночь"',
#  '"Чудовище из Простоквашино", "Ген героя", "Ненастоящий детектив", "Мама и Тама", "Как бы не стало зимы" из анимационного сериала "Простоквашино"',
#  '#ВСЁ_ИСПРАВИТЬ!?!',
#  '#Москва-Руаян',
#  '#ЯВОЛОНТЕР Истории неравнодушных',
#  '(Не)жданный принц',
#  '(Не)идеальный мужчина',
#  '... в стиле JAZZ',
#  '... и я там был',
# ...

# %% [markdown]
# * Чаще всего одни и те же названия фильмов дублируются с разными знаками пунктуации. Например, `'10 лет спустя'` и `'10 лет спустя.'`;
# * Встречаются наименования в верхнем и нижнем регистре, что может стать причиной появления неявных дубликатов в столбце: `'#ЯВОЛОНТЕР Истории неравнодушных'`, или `' Я ПРЕПОД'`;
# * Пробелы в начале и в конце строк.
#
# Дубликаты могли возникнуть ввиду человеческого фактора. Например, при внесении данных в таблицу вручную.
#
# Обработаем неявные дубликаты в столбце `title`:

# %%
# приведём все значения к нижнему регистру с помощью str.lower()
mkrf['title'] = mkrf['title'].str.lower()

# проверим результат
sorted(mkrf['title'].unique())
# Out:
# [' я препод',
#  '"sos" над тайгой',
#  '"v" значит вендетта',
#  '"артишок" анимационный альманах авторских фильмов',
#  '"бежин луг" сергея эйзенштейна',
#  '"державная" размышления 100 лет спустя',
#  '"зеленое яблоко" анимационный альманах выпуск № 7',
#  '"машины песенки". серия "опять новый год!"',
#  '"море"',
#  '"сезон дождей", "диета матроскина", "шарик хочет телефон" из анимационного сериала "простоквашино"',
#  '"старый" новый год',
#  '"уорнер бразерс пикчерз" и "леджендари пикчерз": тихоокеанский рубеж',
#  '"фееринки". серия "фантик спешит на помощь"',
#  '"хороший день", "бог из машины/deus ex", "голод", "психотроника", "темная ночь"',
#  '"чудовище из простоквашино", "ген героя", "ненастоящий детектив", "мама и тама", "как бы не стало зимы" из анимационного сериала "простоквашино"',
#  '#всё_исправить!?!',
#  '#москва-руаян',
#  '#яволонтер истории неравнодушных',
#  '(не)жданный принц',
#  '(не)идеальный мужчина',
#  '... в стиле jazz',
#  '... и я там был',
# ...

# %%
# напишем функцию для замены подстрок элементов в столбце с помощью str.replace() и regex=False
def names_to_str_replace(column, values):
    for old_name, new_name in values:
        mkrf[column] = mkrf[column].str.replace(old_name, new_name, regex=False)

# вызовем функцию 
names_to_str_replace('title', [
    (' .','.'),
    ('/.','.'),
    (' _',''),
    ('._', '.'),
    ('_', '.'),
    (').', ')'),
    (' -', '')
])

# заменим отдельный элемент столбца с помощью replace()
mkrf['title'] = mkrf['title'].replace(
    {
        'астрал. глава 2':'астрал. глава вторая', 
    }
)

# уберём многоточия и решётки в начале названий
# уберём точки, слэши и дефисы в конце названий
# уберём пробелы в начале и в конце строк
mkrf['title'] = mkrf['title'].str.lstrip('...#').str.rstrip('./-').str.strip()

# %%
# проверим результат, применив сортировку по возрастанию
sorted(mkrf['title'].unique())
# Out:
# ['"sos" над тайгой',
#  '"v" значит вендетта',
#  '"артишок" анимационный альманах авторских фильмов',
#  '"бежин луг" сергея эйзенштейна',
#  '"державная" размышления 100 лет спустя',
#  '"зеленое яблоко" анимационный альманах выпуск № 7',
#  '"машины песенки". серия "опять новый год!"',
#  '"море"',
#  '"сезон дождей", "диета матроскина", "шарик хочет телефон" из анимационного сериала "простоквашино"',
#  '"старый" новый год',
#  '"уорнер бразерс пикчерз" и "леджендари пикчерз": тихоокеанский рубеж',
#  '"фееринки". серия "фантик спешит на помощь"',
#  '"хороший день", "бог из машины/deus ex", "голод", "психотроника", "темная ночь"',
#  '"чудовище из простоквашино", "ген героя", "ненастоящий детектив", "мама и тама", "как бы не стало зимы" из анимационного сериала "простоквашино"',
#  '(не)жданный принц',
#  '(не)идеальный мужчина',
#  '007 координаты скайфолл',
#  '007: спектр',
#  '1+1',
#  '1+1. нарушая правила',
#  '1+1: голливудская история',
# ...

# %% [markdown]
# #### Изучение столбца 'type'

# %% [markdown]
# Проверим список уникальных значений в столбце `type`:

# %%
# выведем список уникальных значений
mkrf['type'].unique()
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', ' Художественный', ' Анимационный',
#        'Музыкально-развлекательный'], dtype=object)

# %% [markdown]
# В столбце с типом фильма обнаружили **2** неявных дубликата с лишними пробелами. Они могли возникнуть по техническим причинам, при загрузке или выгрузке данных.
#
# Обработаем дубликаты в столбце:

# %%
# обработаем дубликаты с помощью replace()
mkrf['type'] = mkrf['type'].replace({' Художественный':'Художественный', ' Анимационный':'Анимационный'})

# проверим результат
mkrf['type'].unique()
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', 'Музыкально-развлекательный'], dtype=object)

# %% [markdown]
# #### Изучение столбца 'film_studio'

# %% [markdown]
# Проверим список уникальных значений в столбце `film_studio`:

# %%
# выведем список уникальных значений
sorted(mkrf['film_studio'].unique())
# Out:
# [' АНО "Кинофорум"',
#  ' Ауматик Интертейнмент, Блюмхаус Продакшнз и др.',
#  ' ЗАО "Кинокомпания ФаворитФильм" по заказу ООО "ФАВОРИТ МЕДИА"',
#  ' Константин Фильм, А Эр Ди Дегето Фильм, Дюне Филис, Икури Филмз, Медуза Фильм, У Эф А Интернэшнл Филм энд Ти Ви Продуцион, Юниверсум Филм ',
#  ' ООО "АВАТАРА"',
#  ' ООО "КОСТАФИЛЬМ"',
#  ' ООО "КиноФирма"',
#  ' ООО "Кинокомпания "Студия ПРЕССИНГ"',
#  ' ООО "Магнум-фильм"',
#  ' ООО "Продюсерская фирма Игоря Толстунова"',
#  ' ООО "Студия "Рой"',
#  ' ООО "Студия 25", ООО "Медиа Арт Студио", ООО "Продюсерский центр "Синема Продакшн" ',
#  ' ООО "Студия МЕТРАФИЛЬМС", Компания "TASSE film", Компания "SIRENA film"',
#  ' ООО "ТаББаК"',
#  ' ООО "ТаББаК", ООО "Анимационная студия "Москва"',
#  ' ООО "ТаББаК", ООО "Весёлая Компания"',
#  ' ООО "Форс Медиа"',
#  ' ООО "Хардкор", ООО "Патриот продакшнс"',
#  ' ООО "Энджой мувиз"',
#  ' ООО "Энджой мувиз", ООО "Эмоушен Пикчерз", ООО "РЕНОВАЦИО интертейнмент"',
# ...

# %% [markdown]
# В этом случае, неявные дубликаты могли возникнуть из-за человеческого фактора при передаче лексических единиц с английского языка на русский. Одни и те же слова передаются двумя способами: транскрипцией и транслитерацией.
#
# Например: `Анимейшнз` и `Анимейшнс` (на англ. animations), `Ток` и `Талк` (на англ. talk).
#
# Также встречаются:
#
# * Полное название и его аббревиатура: `Государственная национальная компания` и `ГНК`;
# * Написание одних и тех же названий в верхнем и нижнем регистре: `СТЕЛЛА` и `Стелла`;
# * Использование разных знаков препинания: `'АО "ТНТ-Телесеть", ООО "Продюсерская компания "Среда", ООО "Ника ТВ"',` и `'АО "ТНТ-Телесеть", ООО Продюсерская компания "Среда", ООО "Ника ТВ"'`;
# * Пробелы в начале строк.

# %% [markdown]
# Обработаем дубликаты в столбце:

# %%
# приведём все значения к нижнему регистру c помощью метода str.lower()
mkrf['film_studio'] = mkrf['film_studio'].str.lower()

# проверим результат
sorted(mkrf['film_studio'].unique())
# Out:
# [' ано "кинофорум"',
#  ' ауматик интертейнмент, блюмхаус продакшнз и др.',
#  ' зао "кинокомпания фаворитфильм" по заказу ооо "фаворит медиа"',
#  ' константин фильм, а эр ди дегето фильм, дюне филис, икури филмз, медуза фильм, у эф а интернэшнл филм энд ти ви продуцион, юниверсум филм ',
#  ' ооо "аватара"',
#  ' ооо "кинокомпания "студия прессинг"',
#  ' ооо "кинофирма"',
#  ' ооо "костафильм"',
#  ' ооо "магнум-фильм"',
#  ' ооо "продюсерская фирма игоря толстунова"',
#  ' ооо "студия "рой"',
#  ' ооо "студия 25", ооо "медиа арт студио", ооо "продюсерский центр "синема продакшн" ',
#  ' ооо "студия метрафильмс", компания "tasse film", компания "sirena film"',
#  ' ооо "таббак"',
#  ' ооо "таббак", ооо "анимационная студия "москва"',
#  ' ооо "таббак", ооо "весёлая компания"',
#  ' ооо "форс медиа"',
#  ' ооо "хардкор", ооо "патриот продакшнс"',
#  ' ооо "энджой мувиз"',
#  ' ооо "энджой мувиз", ооо "эмоушен пикчерз", ооо "реновацио интертейнмент"',
# ...

# %%
# вызовем функцию для замены подстрок
names_to_str_replace('film_studio', [
    ('лапс','лэпс'),
    ('мс','мз'),
    ('пикчерс','пикчерз'),
    ('нтэр','нтер'),
    ('эй','ей'),
    ('эшн','ешн'),
    ('иксер', 'икчер'),
    ('втом', 'утом'),
    ('ллевн', 'левен'),
    ('ейв', 'эйв'),
    ('орел', 'орёл'),
    ('групп', 'груп'),
    ('эйшн', 'ейшн'),
    ('азис','айзис'),
    ('айм', 'айэм'),
    ('оад', 'оард'),
    ('ксэль', 'ксель'),
    ('филм', 'фильм'),
    ('иос', 'иоз'),
    ('зоэтроп', 'зоэтроуп'),
    ('зоетроуп', 'зоэтроуп'),
    ('ьюс', 'ьюз'),
    ('би-би-си', 'би би си'),
    ('бибиси', 'би би си'),
    ('талк', 'ток'),
    ('бэн', 'бен'),
    ('бигер','биггер'),
    ('бот', 'боат'),
    ('эдж', 'эйдж'),
    ('шнс', 'шнз'),
    ('ауто', 'авто'),
    ('аума', 'автома'),
    ('айто', 'авто'),
    ('ирзк', 'ирск'),
    ('алианз', 'алльянз'),
    ('монзт', 'монст'),
    ('автономная некоммерческая организация','ано'),
    ('государственная национальная компания', 'гнк'),
    ('анимейшнзз', 'анимейшнз'),
    ('агат фильм / си', 'агат фильм и си'),
    ('ареми продюксьон', 'артеми продюксьон'),
    ('а энд е инди фильмз', 'а энд и индефильмз'),
    ('барс', 'барес'),
    ('акрс энд а мьюл фильмворкс', 'ейкерс энд мьюл фильмворкс'),
    ('87элевен', '87 элевен'),
    ('алианс', 'алльянс'),
    ('альянс', 'алльянс'),
    ('артэ франс синема', 'артэ франсе синема'),
    ('ле пакт', 'лё пакт'),
    ('раи чинема', 'рай синема'),
    ('ейнмент', 'еймент'),
    ('бавариа', 'бавария'),
    ('багдасариан', 'багдасарян'),
    ('бакаро', 'бакару'),
    ('вижуал', 'визуал'),
    ('толк', 'ток'),
    ('блиндинг', 'блайндинг'),
    ('блайдинг', 'блайндинг'),
    ('блюмхаус', 'блюмхауз'),
    ('интертеймент ван', 'интертеймент уан'),
    ('беар', 'беа'),
    ('биар', 'беа'),
    ('бир', 'беа'),
    ('роард', 'роуд'),
    ('брукин', 'броукен'),
    ('вондерволд', 'вондерворлд'),
    ('ворлдвье', 'ворлдвью'),
    ('ворлдвьё', 'ворлдвью'),
    ('им.с.а.герасимова', 'имени с.а. герасимова'),
    ('им. с.а.герасимова', 'имени с.а. герасимова'),
    ('"продюсерская компания "среда"', 'продюсерская компания "среда"'),
    ('им. м.горького', 'им. м. горького'),
    ('им.м.горького', 'им. м. горького'),
    ('сэкл', 'сёкл'),
    ('2.4.7.фильм', '2.4.7. фильм'),
    ('аардам', 'аардман'),
    ('автономное учреждение республики саха (якутия) гнк "сахафильм"', 'ау рс(я) гнк "сахафильм"'),
    ('ау республики саха (якутия) гнк "сахафильм"', 'ау рс(я) гнк "сахафильм"'),
    ('автономное учреждение республики саха (якутия) "гнк "сахафильм"', 'ау рс(я) гнк "сахафильм"'),
    ('приват', 'прайвет')
])

#удалим пробелы в начале и в конце строк с помощью str.strip()
mkrf['film_studio'] = mkrf['film_studio'].str.strip()

# %%
# проверим результат
sorted(mkrf['film_studio'].unique())
# Out:
# ['"дино де лаурентиис" (италия) при участии киностудии "мосфильм"',
#  '"союздетфильм", "мосфильм", "москинокомбинат"',
#  '"студия "птица феникс" татьяны новиковой',
#  '"эскиз и каргин студио"',
#  '02 фильмз, ромбэс медиа',
#  '100 барес, 369 продюксьонес, антен 3 фильм, катманду брендид интертеймент, плюраль - джемпса, прана анимейшн студиоз, телевизион федераль',
#  '100 барес, институто националь де сине и артс аудивизуалес, институто де ла синематографиа и де ла артс аудивизуалес, министеро де култура, телевизион федераль, торнасол фильм',
#  '100 барес, канал + испания, хаддок фильм, институто националь сине арте аудивизуаль, институто де кредито офисиаль, телевидение испании, федеральное телевидение, торнасол фильмз',
#  '1000 айз, брон криейтив студиоз, нью лайн синема',
#  '1212 интертеймент, си би эс фильмз, ди ди уай, интертеймент уан, шон дэниэл компани',
#  '1492 пикчерз, коламбиа пикчерз, хэппи медисон пикчерз',
# ...

# %% [markdown]
# #### Изучение столбца 'director'

# %% [markdown]
# Проверим список уникальных значений столбца `director`:

# %%
# выведем список уникальных значений
sorted(mkrf['director'].unique())
# Out:
# [' Йохан Нийенхейс',
#  ' Н.Орлов, Р.Быков',
#  ' Р.Асхаев',
#  ' Т.Саакян',
#  ' Ф.Бондарчук',
#  'Ёлкин Туйчиев',
#  'Ён Сан-хо',
#  'А Андрющенко',
#  'А. Калюжный',
#  'А. Кутерье',
#  'А.А.Эшпай',
#  'А.Аббасов',
#  'А.Абидова (псевдоним Аниса Сабири)',
#  'А.Аболс',
#  'А.Агаджанян',
#  'А.Адилханян',
#  'А.Адраникян',
#  'А.Аксененко',
#  'А.Аксененко, Э.Никогосян, Д.Дюжев, А.Вакулов (А.Кульбицкий)',
#  'А.Алов, В.Наумов',
#  'А.Аманшаев, Г.Шенгелия',
#  'А.Амбросьев',
#  'А.Амиров',
#  'А.Ананикян, В.Рейнгеверц',
#  'А.Андрианов',
#  'А.Андризани, А.Бардани, В.Карнелутти, Ф.Коста,  Г.С.Нардис, В.Пальмьери, В.Чеа, А.Юлиано ',
#  'А.Анненский',
#  'А.Аравин',
#  'А.Аравин, А.Прошкин',
#  'А.Арпеньтеньер, А.Бариларо, М.Бланчес, Р.Валлей, Л.Гранд, Ф.Дион, А.Жасина, Э.Коэтс,  Лу Хаму-Лхад, П.Осборн, Т.Ушев',
#  'А.Артамонова',
#  'А.Арутюнов',
#  'А.Арутюнян, А.Коршунов',
#  'А.Атанесян',
#  'А.Бадягина',
#  'А.Бажанов',
#  'А.Балабанов',
#  'А.Балахонов',
#  'А.Бальчев',
# ...

# %% [markdown]
# В столбце можно заметить:
#
# * Неявные дубликаты имён режиссёров, которые возникли из-за наличия псевдонимов в таблице. Например: `'А.Михалков (псевдоним А.Кончаловский)'`, `'А.Кончаловский'`, `'А.Михалков-Кончаловский'` и `'А.Михалков'`;
# * Неявные дубликаты в результате разных способов перевода одного и того же имени на русский язык: `'Вольфганг Петерсон'` и `'Вольфганг Петерсен'`.
#
# Также видны строки с пробелами в начале и лишними пробелами после точки, отсутствие точки.
#
# Обработаем дубликаты:

# %%
# вызовем функцию для замены подстрок
names_to_str_replace('director', [
    ('. ','.')
])

# проверим результат
sorted(mkrf['director'].unique())
# Out:
# [' Йохан Нийенхейс',
#  ' Н.Орлов, Р.Быков',
#  ' Р.Асхаев',
#  ' Т.Саакян',
#  ' Ф.Бондарчук',
#  'Ёлкин Туйчиев',
#  'Ён Сан-хо',
#  'А Андрющенко',
#  'А.А.Эшпай',
#  'А.Аббасов',
#  'А.Абидова (псевдоним Аниса Сабири)',
#  'А.Аболс',
#  'А.Агаджанян',
#  'А.Адилханян',
#  'А.Адраникян',
#  'А.Аксененко',
#  'А.Аксененко, Э.Никогосян, Д.Дюжев, А.Вакулов (А.Кульбицкий)',
#  'А.Алов, В.Наумов',
#  'А.Аманшаев, Г.Шенгелия',
#  'А.Амбросьев',
#  'А.Амиров',
#  'А.Ананикян, В.Рейнгеверц',
#  'А.Андрианов',
#  'А.Андризани, А.Бардани, В.Карнелутти, Ф.Коста,  Г.С.Нардис, В.Пальмьери, В.Чеа, А.Юлиано ',
#  'А.Анненский',
#  'А.Аравин',
#  'А.Аравин, А.Прошкин',
#  'А.Арпеньтеньер, А.Бариларо, М.Бланчес, Р.Валлей, Л.Гранд, Ф.Дион, А.Жасина, Э.Коэтс,  Лу Хаму-Лхад, П.Осборн, Т.Ушев',
#  'А.Артамонова',
#  'А.Арутюнов',
#  'А.Арутюнян, А.Коршунов',
#  'А.Атанесян',
#  'А.Бадягина',
#  'А.Бажанов',
#  'А.Балабанов',
#  'А.Балахонов',
#  'А.Бальчев',
#  'А.Баранов',
#  'А.Баршак',
# ...

# %% [markdown]
# Так как часто в качестве режиссера выступает продюсер и наоборот, режисер в качестве продюсера - сохраним словарь с именами и псевдонимами режиссеров и продюсеров для замены строк:

# %%
# сохраним имена и псевдонимы в словарь directors_and_producers
directors_and_producers_dict = {
    'Ж.Крыжовников': 'А.Першин (псевдоним Ж.Крыжовников)',
    'А.Першин':'А.Першин (псевдоним Ж.Крыжовников)',
    'А.Соколов':'А.Соколов-Дворников (псевдоним - Алексей Соколов)',
    'А.Абидова':'А.Абидова (псевдоним Аниса Сабири)',
    'Аниса Сабири':'А.Абидова (псевдоним Аниса Сабири)',
    'М.Бальчюнас':'М.Бальчюнас (псевдоним Марюс Вайсберг)',
    'Марюс Вайсберг':'М.Бальчюнас (псевдоним Марюс Вайсберг)',
    'М.Вайсберг':'М.Бальчюнас (псевдоним Марюс Вайсберг)',
    'А.Сабири':'А.Абидова (псевдоним Аниса Сабири)',
    'А.Вакулов':'А.Вакулов (А.Кульбицкий)',
    'А.Кульбицкий':'А.Вакулов (А.Кульбицкий)',
    'А.Дворников':'А.Соколов-Дворников (псевдоним - Алексей Соколов)',
    'А.Нужный':'А.Черномазов (псевдоним Алексей Нужный)',
    'А.Черномазов':'А.Черномазов (псевдоним Алексей Нужный)',
    'А Андрющенко':'А.Андрющенко',
    'А.Михалков':'А.Михалков (псевдоним А.Кончаловский)',
    'А.Кончаловский':'А.Михалков (псевдоним А.Кончаловский)',
    'А.Михалков-Кончаловский':'А.Михалков (псевдоним А.Кончаловский)',
    'А.Новиков':'А.Новиков (псевдоним - Александр Новиков-Янгинов)',
    'А.Янгинов':'А.Новиков (псевдоним - Александр Новиков-Янгинов)',
    'А.Рожнова':'"А.Рожнова (псевдоним Александра Р\'ЮЖ)"',
    'Александра Р\'ЮЖ':'"А.Рожнова (псевдоним Александра Р\'ЮЖ)"',
    'А.Евсеев':'А.Евсеев (псевдоним - Хант)',
    'Хант':'А.Евсеев (псевдоним - Хант)',
    'А.Федосеенко':'А.Федосеенко (псевдоним Ангелина Никонова)',
    'А.Никонова':'А.Федосеенко (псевдоним Ангелина Никонова)',
    'А.Шелехов':'А.Шелехов (псевдоним Александр Шелл)',
    'Александр Шелл':'А.Шелехов (псевдоним Александр Шелл)',
    'А.Шелл':'А.Шелехов (псевдоним Александр Шелл)',
    'А.Безрукова':'А.Безрукова (псевдоним - Анна Матисон)',
    'А.Матисон':'А.Безрукова (псевдоним - Анна Матисон)',
    'Анна Матисон':'А.Безрукова (псевдоним - Анна Матисон)',
    'В.Гришин':'В.Гришин (псевдоним - Влад Гришин)',
    'Влад Гришин':'В.Гришин (псевдоним - Влад Гришин)',
    'В.Кушнирович':'В.Кушнирович (псевдоним В.Бенигсен)',
    'В.Бенигсен':'В.Кушнирович (псевдоним В.Бенигсен)',
    'А.Вайсман':'А.Вайсман (псевдоним - Белый)',
    'А.Белый':'А.Вайсман (псевдоним - Белый)',
    'Ангелина Подорожная':'А.Коновальцева (псевдоним Ангелина Подорожная)',
    'А.Коновальцева':'А.Коновальцева (псевдоним Ангелина Подорожная)',
    'Алекс Йоку':'А.Иванов (псевдоним - Алекс Йоку)'
}

# %% [markdown]
# Аналогично сохраним список кортежей с переводом иностранных имён и фамилий для замены подстрок:

# %%
directors_and_producers_tuple = [
    ('Петерсон','Петерсен'),
    ('Винделев', 'Винделов'),
    ('Вассим Бежи', 'Вассим Беджи'),
    ('Сотстков', 'Сотсков'),
    ('Бэйзил Айваник','Бэзил Иваник'),
    ('Бэзил Айваник','Бэзил Иваник'),
    ('Джоел Сильвер', 'Джоэл Силвер'),
    ('Грэйзер','Грейзер'),
    ('А.Косове', 'А.Косов'),
    ('Арнолд', 'Арнольд'),
    ('Мартин Бауэн','Марти Бауэн'),
    ('Банелло', 'Бонелло'),
    ('Белью', 'Беллью'),
    ('Голдманн','Голдман'),
    ('Атьенца', 'Атьенса'),
    ('Барнаби', 'Барнеби'),
    ('Антритрадж', 'Амритрадж'),
    ('Джи Уилсон', 'Дж.Уилсон'),
    ('Фишман', 'Фичман'),
    ('Лонгария', 'Лонгория'),
    ('Агустин', 'Аугустин'),
    ('Алине', 'Алина'),
    ('Гольдман', 'Голдман'),
    ('Сайфуллина', 'Сайфулина'),
    ('Аттал', 'Атталь'),
    ('Болинг', 'Боулин'),
    ('Гуерра', 'Герра'),
    ('Пателье', 'Пательер'),
    ('Фергюссон', 'Фергюсон'),
    ('Барды', 'Барди'),
    ('Бардю', 'Барди'),
    ('Вирджиния Силла', 'Виржини Силла'),
    ('Атталььь','Атталь'),
    ('Аттальььь','Атталь'),
    ('Аттальь','Атталь'),
    ('Гарсиа','Гарсия'),
    ('Чиарино','Кьярино'),
    ('Арэд','Арад'),
    ('Майкл Фоттрелл','Майкл Фоттрел'),
    ('Берд', 'Бёрд')
]

# %%
# вызовем функцию и заменим фрагменты строк
names_to_str_replace('director', directors_and_producers_tuple)

# заменим отдельные элементы целиком
mkrf['director'] = mkrf['director'].replace(directors_and_producers_dict) 

# удалим лишние пробелы в начале и в конце строк
mkrf['director'] = mkrf['director'].str.strip()

# %%
# проверим результат
sorted(mkrf['director'].unique())
# Out:
# ['Ёлкин Туйчиев',
#  'Ён Сан-хо',
#  'А.А.Эшпай',
#  'А.Аббасов',
#  'А.Абидова (псевдоним Аниса Сабири)',
#  'А.Аболс',
#  'А.Агаджанян',
#  'А.Адилханян',
#  'А.Адраникян',
#  'А.Аксененко',
#  'А.Аксененко, Э.Никогосян, Д.Дюжев, А.Вакулов (А.Кульбицкий)',
#  'А.Алов, В.Наумов',
#  'А.Аманшаев, Г.Шенгелия',
#  'А.Амбросьев',
#  'А.Амиров',
#  'А.Ананикян, В.Рейнгеверц',
#  'А.Андрианов',
#  'А.Андризани, А.Бардани, В.Карнелутти, Ф.Коста,  Г.С.Нардис, В.Пальмьери, В.Чеа, А.Юлиано',
#  'А.Андрющенко',
#  'А.Анненский',
#  'А.Аравин',
#  'А.Аравин, А.Прошкин',
#  'А.Арпеньтеньер, А.Бариларо, М.Бланчес, Р.Валлей, Л.Гранд, Ф.Дион, А.Жасина, Э.Коэтс,  Лу Хаму-Лхад, П.Осборн, Т.Ушев',
#  'А.Артамонова',
#  'А.Арутюнов',
#  'А.Арутюнян, А.Коршунов',
#  'А.Атанесян',
#  'А.Бадягина',
#  'А.Бажанов',
#  'А.Балабанов',
#  'А.Балахонов',
#  'А.Бальчев',
#  'А.Баранов',
#  'А.Баршак',
#  'А.Барщевский, И.Матвеев',
#  'А.Барыкин',
#  'А.Басаев',
#  'А.Басов',
#  'А.Безрук',
# ...

# %% [markdown]
# #### Изучение столбца 'producer'

# %% [markdown]
# Проверим список уникальных значений столбца `producer`:

# %%
# выведем список уникальных значений
sorted(mkrf['producer'].unique())
# Out:
# [' А.Шальопа',
#  ' Г.Шпригов',
#  ' Дитмар Ганше, Филипп Фогес,  Бенджамин Херрман, Миша Хоффманн, Эберхард Юнексдорф, Энн Мередит',
#  ' И.Гелашвили',
#  ' К.Шахназаров, А.Златопольский',
#  ' Мишель Чиджик, Джефф Абберли, Натали Марисано',
#  ' ООО "Арт Пикчерс Студия"',
#  ' ООО "Арт Пикчерс Студия", ФГУП "ВГТРК"',
#  ' ООО "КиноФирма"',
#  ' ФГУП "Киноконцерн "Мосфильм"',
#  '"Фонд Михаила Калатозова"',
#  'Ёсиаки Нисимура, Джеффри Уэкслер',
#  'А. Калюжный',
#  'А. Натахин',
#  'А.А.Эшпай',
#  'А.Аболс',
#  'А.Адамская',
#  'А.Адраникян, В.Горяинов',
#  'А.Ананикян',
#  'А.Ананикян, Г.Андреасян, С.Андреасян',
#  'А.Ананикян, С.Андреасян, Г.Андреасян',
#  'А.Аствацатрян, С.Сельянов',
#  'А.Атанесян, А.Кириллин, Л.Тарасов',
#  'А.Атанесян, М.Бабаханов, Р.Бутко',
#  'А.Атанесян, Р.Атоян',
#  'А.Балашов',
#  'А.Барыкин',
#  'А.Барыкин, В.Братухин, О.Суров',
#  'А.Басов',
#  'А.Белов',
#  'А.Берденников',
#  'А.Бессчетнова, М.Евдокимова, А.Куренков',
#  'А.Бзаров',
# ...

# %% [markdown]
# В столбце с именами продюсеров были обнаружены следующие проблемы:
#
# * Наименования киностудий, например: `' ООО "Арт Пикчерс Студия"'` или `' ФГУП "Киноконцерн "Мосфильм"'`;
# * Лишние пробелы в строках: `' Г.Шпригов'` или `'А. Калюжный'`;
# * Разные способы перевода имён на русский язык: `'Вольфганг Петерсен'` и `'Вольфганг Петерсон'`;
# * Как и у режиссёров, наличие псевдонимов у продюсеров: `'М.Бальчюнас (псевдоним Марюс Вайсберг)'` или `'"А.Рожнова (псевдоним Александра Р'ЮЖ)"'`.
#
# Проблемы и дубликаты могли возникнуть как в результате человеческого, так и технического фактора: выбора разных способов перевода и опечаток при внесении данных в таблицу, загрузке и выгрузке данных.
#
# Обработаем значения в столбце:

# %%
# вызовем функцию для замены фрагментов строк
names_to_str_replace('producer', directors_and_producers_tuple)

# уберём лишний пробел после точки
names_to_str_replace('producer', [
    ('. ','.')
])

# заменим отдельные строки с именами и псевдонимами
mkrf['producer'] = mkrf['producer'].replace(directors_and_producers_dict)

# заменим отдельные строки с названиями киностудий 
mkrf['producer'] = mkrf['producer'].replace(
    {
        ' ООО "Арт Пикчерс Студия"':'неизвестно',
        ' ООО "Арт Пикчерс Студия", ФГУП "ВГТРК"':'неизвестно',
        ' ООО "КиноФирма"':'неизвестно',
        ' ФГУП "Киноконцерн "Мосфильм"':'неизвестно',
        'АНО Студия "Остров", Государственная телевизионная компания "Телеканал "Россия", Международный Олимпийский комитет':'неизвестно',
        'АНО Школа-студия анимационного кино "Шар"':'неизвестно',
        '"Фонд Михаила Калатозова"':'неизвестно',
        'Аншутц Интертейнмент Групп':'неизвестно',
    })

# уберём лишние пробелы в строках
mkrf['producer'] = mkrf['producer'].str.strip()

# %%
# проверим результат
sorted(mkrf['producer'].unique())
# Out:
# ['Ёсиаки Нисимура, Джеффри Уэкслер',
#  'А.А.Эшпай',
#  'А.Аболс',
#  'А.Адамская',
#  'А.Адраникян, В.Горяинов',
#  'А.Ананикян',
#  'А.Ананикян, Г.Андреасян, С.Андреасян',
#  'А.Ананикян, С.Андреасян, Г.Андреасян',
#  'А.Аствацатрян, С.Сельянов',
#  'А.Атанесян, А.Кириллин, Л.Тарасов',
#  'А.Атанесян, М.Бабаханов, Р.Бутко',
#  'А.Атанесян, Р.Атоян',
#  'А.Балашов',
#  'А.Барыкин',
#  'А.Барыкин, В.Братухин, О.Суров',
#  'А.Басов',
#  'А.Белов',
#  'А.Бессчетнова, М.Евдокимова, А.Куренков',
#  'А.Бзаров',
#  'А.Бик, П.Бранкати, Ф.Будвег, М.де Конинг, П.А.Марион, Г.Мендеш, М.Ситер,',
#  'А.Бирюкова, Д.Давиденко',
#  'А.Бобин',
#  'А.Болонин, В.Тартаковский',
#  'А.Боярский, В.Конг Жао, Д.Лассетер, К.О.Рурк, П.Пиерарт, Д.Херцфельд, Д.Хэнкок',
#  'А.Боярский, С.Сельянов',
#  'А.Боярский, С.Сельянов, А.Златопольский',
#  'А.Боярский,Ю С.Сельянов, Д.Ловейко, О.Кузовков, А.Добрунов',
#  'А.Броварец',
#  'А.Бурлов, Б.Цыденешеев, А.Мяханова, Э.Тимурова, А.Цыренов, Д.Ользонов',
# ...

# %% [markdown]
# #### Изучение столбцов 'age_restriction', 'financing_source'

# %% [markdown]
# Проверим список уникальных значений столбца `age_restriction`:

# %%
# выведем список уникальных значений
sorted(mkrf['age_restriction'].unique())
# Out:
# ['«0+» - для любой зрительской аудитории',
#  '«12+» - для детей старше 12 лет',
#  '«16+» - для детей старше 16 лет',
#  '«18+» - запрещено для детей',
#  '«6+» - для детей старше 6 лет']

# %% [markdown]
# В столбце с возрастным ограничением отсутсвуют неявные дубликаты. Вернёмся к этому столбцу позже, на этапе категоризации данных.

# %% [markdown]
# Проверим список уникальных значений столбца `financing_source`:

# %%
sorted(mkrf['financing_source'].unique())
# Out:
# ['Министерство культуры',
#  'Министерство культуры, Фонд кино',
#  'Фонд кино',
#  'неизвестно']

# %% [markdown]
# В столбце с источником финансирования отсутствуют неявные дубликаты.

# %% [markdown]
# #### Изучение столбцов 'production_country', 'genres'

# %% [markdown]
# Проверим список уникальных значений столбца `production_country`:

# %%
# выведем список уникальных значений
sorted(mkrf['production_country'].unique())
# Out:
# [' СССР',
#  ' СССР ',
#  ' СССР   ',
#  '2019',
#  'CША',
#  'Австралия',
#  'Австралия - Великобритания - Бельгия - Индия',
#  'Австралия - Германия',
#  'Австралия - Ирландия',
#  'Австралия - Колумбия',
#  'Австралия - США',
#  'Австралия, Канада',
#  'Австралия, США',
#  'Австралия-Великобритания',
#  'Австралия-Ирландия',
#  'Австралия-США',
#  'Австралия-Турция-США',
#  'Австрия',
#  'Австрия - Германия',
#  'Австрия - Германия - Франция',
#  'Австрия - Люксембург',
#  'Австрия, Великобритания, Германия',
#  'Австрия-Германия-Франция',
#  'Австрия-Франция-Германия',
#  'Азербайджан-Россия',
#  'Аргентина',
#  'Аргентина - Бразилия',
#  'Аргентина - Испания',
#  'Аргентина - Испания - Уругвай',
#  'Аргентина - Мексика - Бразилия - Франция - США',
#  'Аргентина - Уругвай - Россия - Германия - Франция - Нидерланды',
#  'Аргентина - Франция - Испания',
#  'Аргентина, Испания',
#  'Аргентина-Испания',
#  'Армения',
#  'Армения - Германия',
#  'Армения - Казахстан',
# ...

# %% [markdown]
# В столбце заметны неявные дубликаты, которые могли возникнуть по техническим причинам при загрузке данных или в результате опечаток при внесении данных вручную:
#
# * Пробелы по краям строк: `' СССР'` или `' СССР   '`;
# * Латинский символ `'C'` в слове `CША` вместо кириллицы;
# * Перечисление стран через разные пунктуационные знаки: `'Австрия-Германия-Франция'` и `'Австрия - Германия - Франция'`;
# `'Великобритания - США'` и `'Великобритания, США'`;
# * Знак препинания в середине слова: `К;анада` и `Канада`.
#
# А также некорректное значение - год `'2019'` вместо названия страны.
#
# Обработаем дубликаты в столбце:

# %%
# вызовем функцию для замены подстрок
names_to_str_replace('production_country', [
    (',', '-'),
    ('- ', '-'),
    (' - ', '-'),
    (' -', '-'),
    ('2019', 'неизвестно'),
    ('CША', 'США'),
    ('К;анада', 'Канада')
])

# удалим пробелы в конце и в начале строк
mkrf['production_country'] = mkrf['production_country'].str.strip()

# %%
# проверим результат
sorted(mkrf['production_country'].unique())
# Out:
# ['Австралия',
#  'Австралия-Великобритания',
#  'Австралия-Великобритания-Бельгия-Индия',
#  'Австралия-Германия',
#  'Австралия-Ирландия',
#  'Австралия-Канада',
#  'Австралия-Колумбия',
#  'Австралия-США',
#  'Австралия-Турция-США',
#  'Австрия',
#  'Австрия-Великобритания-Германия',
#  'Австрия-Германия',
#  'Австрия-Германия-Франция',
#  'Австрия-Люксембург',
#  'Австрия-Франция-Германия',
#  'Азербайджан-Россия',
#  'Аргентина',
#  'Аргентина-Бразилия',
#  'Аргентина-Испания',
#  'Аргентина-Испания-Уругвай',
#  'Аргентина-Мексика-Бразилия-Франция-США',
#  'Аргентина-Уругвай-Россия-Германия-Франция-Нидерланды',
#  'Аргентина-Франция-Испания',
#  'Армения',
#  'Армения-Германия',
#  'Армения-Казахстан',
#  'Армения-Россия',
#  'Бельгия',
#  'Бельгия-Великобритания-США',
#  'Бельгия-Германия-Канада-Франция-США-Великобритания',
#  'Бельгия-Германия-Люксембург',
#  'Бельгия-Германия-Люксембург-Франция',
#  'Бельгия-Испания-Канада-Нидерланды',
#  'Бельгия-Италия-Франция',
# ...

# %% [markdown]
# Отметим, что в столбце встречается один и тот же набор стран, перечисленных в разном порядке. Например: `'Австралия-Германия' и 'Германия-Австралия'`. Мы не будем считать такие строки неявными дубликатами, так как расположение стран может говорить о наибольшем / наименьшем участии той или иной страны в создании фильма.

# %% [markdown]
# Проверим список уникальных значений столбца `genres`:

# %%
sorted(mkrf['genres'].unique())
# Out:
# ['аниме,мультфильм',
#  'аниме,мультфильм,боевик',
#  'аниме,мультфильм,детектив',
#  'аниме,мультфильм,драма',
#  'аниме,мультфильм,комедия',
#  'аниме,мультфильм,короткометражка',
#  'аниме,мультфильм,мелодрама',
#  'аниме,мультфильм,приключения',
#  'аниме,мультфильм,ужасы',
#  'аниме,мультфильм,фантастика',
#  'аниме,мультфильм,фэнтези',
#  'биография',
#  'биография,военный,драма',
#  'биография,документальный',
#  'биография,драма',
#  'биография,драма,военный',
#  'биография,драма,история',
#  'биография,драма,криминал',
#  'биография,история',
#  'биография,история,драма',
#  'биография,криминал,драма',
#  'биография,криминал,триллер',
#  'биография,мелодрама,драма',
#  'биография,музыка,драма',
#  'биография,музыка,мюзикл',
#  'биография,спорт,драма',
#  'биография,спорт,история',
#  'биография,спорт,комедия',
#  'боевик',
#  'боевик,вестерн,приключения',
#  'боевик,военный',
#  'боевик,военный,драма',
#  'боевик,военный,история',
#  'боевик,детектив',
#  'боевик,драма',
# ...

# %% [markdown]
# В столбце `genres`, как и в `production_country`, встречается один и тот же набор жанров, перечисленных в разном порядке.
# Например: `'ужасы,триллер'` и `'триллер,ужасы,'`.
#
# Мы также не будем считать такие строки неявными дубликатами, так как расположение жанра может показывать, насколько он превалирует в фильме.

# %% [markdown]
# ### Изучение столбцов с количественными переменными: обработка аномальных значений

# %% [markdown]
# Изучим и очистим от аномалий столбцы с числами: `refundable_support`, `nonrefundable_support`, `budget` и `box_office`.
#
# * Рассмотрим каждую гистограмму более детально.
# * Ознакомимся с числовым описанием данных каждого столбца.
# * Построим диаграмму размаха для каждого столбца и рассчитаем межквартильный размах.

# %% [markdown]
# #### Изучение столбца 'refundable_support'

# %% [markdown]
# Ознакомимся с гистограммой по столбцу с объёмом возвратных средств государственной поддержки — `refundable_support`:

# %%
# построим гистограмму с 50 корзинами
mkrf['refundable_support'].hist(edgecolor='black', bins=50)

# обозначим название графика 
# назовём оси 'y' и 'x'
plt.title('Объём возвратных средств государственной поддержки')
plt.ylabel('Количество фильмов')
plt.xlabel('Государственная поддержка в ₽')

# выведем на экран
plt.show()

# %% [markdown]
# Данные распределены неравномерно:
#
# * Виден выраженный узкий пик на значении **0**. Далее количество фильмов резко снижается примерно до **12**, а затем опускается до **0** в районе `22 000 000 рублей`.
# * После отметки `50 000 000 рублей` заметны редкие, особенно крупные значения: `75 000 000`, `100 000 000` и больше.

# %% [markdown]
# Дополним гистограмму числовым описанием данных:

# %%
mkrf['refundable_support'].describe()
# Out:
# count    3.320000e+02
# mean     1.186446e+07
# std      2.491656e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.500000e+07
# max      1.800000e+08
# Name: refundable_support, dtype: float64

# %% [markdown]
# * Минимальное значение, первый квартиль и медиана равны **0**. Следует проверить данные на наличие ошибок и установить возможную причину большого количества нулевых значений.
# * Среднее выше медианы и составляет **1.1**. Стандартное отклонение — **2.4**. Вероятно, в данных есть аномалии или выбросы.
# * Максимальное значение — **180 000 000 ₽**. Можно предположить, что это единичное крупное значение — выброс.

# %% [markdown]
# Построим диаграмму размаха, чтобы проверить столбец на наличие выбросов и аномальных значений:

# %%
# построим диаграмму размаха по столбцу 
mkrf.boxplot(column='refundable_support')

# обозначим название диаграммы, параметром pad настроим высоту заголовка
# поставим метки на оси 'y' с шагом 10_000_000 
# назовём ось 'y'
plt.title('Объём возвратных средств государственной поддержки', pad=20)
plt.yticks(range(0, 180_000_000, 10_000_000))
plt.ylabel('Государственная поддержка в ₽')

# выведем на экран
plt.show()

# %% [markdown]
# * Выбросы почти достигают отметки в `120 000 000`, далее видны особенно крупные значения — `150 000 000` и `180 000 000 рублей`.

# %% [markdown]
# Посмотрим на фильмы с нулевым значением в столбце:

# %%
# напишем функцию для фильтрации значений
def filtered_data(data, column, value_1, value_2):
    return data[(data[column] >= value_1) & (data[column] <= value_2)]

# выведем результат на экран
filtered_data(mkrf, 'refundable_support', 0, 0)
# Out:
#                              title  pu_number           show_start_date  \
# 1281                 пока еще жива  111005313 2013-10-11 12:00:00+00:00
# 1448           бесславные придурки  111003314 2014-03-28 12:00:00+00:00
# 1498                     невидимки  111004213 2013-09-10 12:00:00+00:00
# 1524                         берцы  111004314 2014-05-05 12:00:00+00:00
# 1792                      братья ч  111004414 2014-04-23 12:00:00+00:00
# ...                            ...        ...                       ...
# 7290       урфин джюс возвращается  114004019 2019-10-14 12:00:00+00:00
# 7320             новогодний ремонт  111018219 2019-11-07 12:00:00+00:00
# 7330  лев яшин. вратарь моей мечты  111018719 2019-11-21 12:00:00+00:00
# 7344                 кроличья лапа  111018919 2019-11-20 12:00:00+00:00
# 7476                    я свободен  111023019 2019-12-26 12:00:00+00:00
#
#                 type                                        film_studio  \
# ...

# %% [markdown]
# * Несмотря на отсутствие возвратных средств государственной поддержки, государственные организации, такие как `Министерство культуры` и `Фонд кино`, выделили картинам невозвратные средства поддержки. Также указан бюджет.
#
# В этом случае, значение **0** соответствует действительности. Иногда не требуется возвращать средства государству. Например, если речь идёт о детских фильмах или социально значимом кино.

# %% [markdown]
# Посмотрим минимальное значение в столбце, исключив нулевое:

# %%
# отфильтруем значения столбца и выведем минимальное 
mkrf['refundable_support'][mkrf['refundable_support'] != 0].min()
# Out:
# 3500000

# %% [markdown]
# Ознакомимся с информацией о фильмах с объёмом возвратных средств государственной поддержки `от 3 500 000 до 5 000 000`:

# %%
# выведем результат на экран
filtered_data(mkrf, 'refundable_support', 3_500_000, 5_000_000)
# Out:
#                                   title  pu_number           show_start_date  \
# 2982  сдается дом со всеми неудобствами  111008016 2016-04-27 12:00:00+00:00
# 3041                        30 свиданий  111020815 2015-12-10 12:00:00+00:00
# 3230                            невеста  111016516 2016-10-25 12:00:00+00:00
# 3482              бременские разбойники  114003416 2016-11-01 12:00:00+00:00
# 3553            сказ о петре и февронии  114001517 2017-06-06 12:00:00+00:00
# 3783                         блокбастер  111004117 2017-05-31 12:00:00+00:00
# 5517                            конверт  111007217 2017-11-30 12:00:00+00:00
# 5932                          проводник  111006518 2018-11-29 12:00:00+00:00
# 7322                              успех  111018519 2019-11-04 12:00:00+00:00
# 7375                              тварь  111019419 2019-11-26 12:00:00+00:00
#
#                 type                                        film_studio  \
# ...

# %% [markdown]
# * После фильмов с минимальным значением в `3 500 000` сразу следуют фильмы с объёмом средств — `5 000 000`.
# * Запись с минимальным объёмом средств — художественный фильм `'Сдается дом со всеми неудобствами'` от `2016-04-27`, с невысоким рейтингом — `5.8` и маленьким объёмом сборов в рублях — всего `55 800 рублей`.
#
# Несмотря на маленькие сборы, значение вполне реалистично. Неудача фильма в прокате может быть связана с плохой рекламой или слабым сценарием.

# %% [markdown]
# Рассчитаем межквартильный размах, чтобы наиболее точно определить верхнюю границу выбросов:

# %%
# напишем функцию для расчётов с параметром - столбцом датафрейма
def emission_limit(data, column):

# рассчитаем первый квартиль - 25%
# рассчитаем второй квартиль - 75%
# рассчитаем межквартильный размах - IQR
# вычислим верхнюю границу для выбросов
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    return f'Верхняя граница выбросов = {upper_limit:.2f}'

# вызовем функцию и выведем результат на экран
emission_limit(mkrf, 'refundable_support')
# Out:
# 'Верхняя граница выбросов = 37500000.00'

# %% [markdown]
# Согласно расчётам, верхняя граница нормального размаха составляет — `37 500 000 рублей`.

# %% [markdown]
# Отфильтруем значения в столбце:

# %%
# создадим копию исходного датафрейма
good_mkrf = mkrf.copy()

# отфильтруем строки датафрейма, у которых значение в столбце выше 37_500_000
# оставим строки с NaN в столбце с помощью isna()
good_mkrf = good_mkrf[(mkrf['refundable_support'] <= 37_500_000) | good_mkrf['refundable_support'].isna()]

# проверим результат
good_mkrf['refundable_support'].sort_values(ascending=False)
# Out:
# 2970    36000000
# 6627    35000000
# 2773    30000000
# 3708    30000000
# 2142    30000000
#           ...
# 7481        <NA>
# 7482        <NA>
# 7483        <NA>
# 7484        <NA>
# 7485        <NA>
# Name: refundable_support, Length: 7445, dtype: Int64

# %% [markdown]
# Cравним результат предобработки, наложим гистограмму датафрейма до фильтрации — `mkrf` на гистограмму очищенных данных в `good_mkrf`:

# %%
# построим гистограммы на основе исходных данных
ax = mkrf.plot(
    kind='hist',
    y='refundable_support',
    histtype='step',
    range=(0, 180_000_000),
    bins=50,
    linewidth=5,
    alpha=0.7,
    label='raw',
)
# накладываем на гистограмму после предобработки данных
good_mkrf.plot(
    kind='hist',
    y='refundable_support',
    histtype='step',
    range=(0, 180_000_000),
    bins=50,
    linewidth=4,
    alpha=0.7,
    label='filtered',
    ax=ax,
    grid=True,
    legend=True,
) 

# дадим название графику и осям
ax.set_title('Объём возвратных средств государственной поддержки')
ax.set_xlabel('Государственная поддержка в ₽')
ax.set_ylabel('Количество фильмов')
# Out:
# Text(0, 0.5, 'Количество фильмов')

# %% [markdown]
# **Вывод:**
#
# * Оставили нулевые значения в таблице, так как картинам могли выделить другой вид поддержки — невозвратные средства.
# * Отфильтровали датафрейм по верхней границе нормального размаха, удалили значения выше `37 500 000 рублей`.
# * После фильтрации данных распределение в столбце фатафрейма стало более концентрированным. Это позволит избежать искажений при дальнейшем анализе.

# %% [markdown]
# #### Изучение столбца 'nonrefundable_support'

# %% [markdown]
# Ознакомимся с гистограммой по столбцу с объёмом невозвратных средств государственной поддержки — `nonrefundable_support`:

# %%
# построим гистограмму с 50 корзинами
mkrf['nonrefundable_support'].hist(edgecolor='black', bins=50)

# обозначим название графика 
# назовём оси 'y' и 'x'
plt.title('Объём невозвратных средств государственной поддержки')
plt.ylabel('Количество фильмов')
plt.xlabel('Государственная поддержка в ₽')

# выведем на экран
plt.show()

# %% [markdown]
# Распределение в столбце с объёмом невозвратных средств государственной поддержки выглядит более равномерно, чем в столбце с возвратными средствами. Однако можно заметить следующие проблемы:
#
# * Узкий пик у значения в приблизительно `22 000 000`.
# * Длинный хвост `до 150 000 000 рублей`, далее — более редкие высокие значения вплоть `до 400 000 000 рублей`.

# %% [markdown]
# Дополним гистограмму числовым описанием данных:

# %%
# выведем числовое описание данных с помощью describe()
mkrf['nonrefundable_support'].describe()
# Out:
# count    3.320000e+02
# mean     4.898099e+07
# std      5.998012e+07
# min      0.000000e+00
# 25%      2.500000e+07
# 50%      3.000000e+07
# 75%      4.037500e+07
# max      4.000000e+08
# Name: nonrefundable_support, dtype: float64

# %% [markdown]
# * Среднее выше медианы на **1.8**, достаточно высокое стандартное отклонение — **5.9**. Скорее всего, присутствуют выбросы или аномалии.
# * Сомнения вызывает минимальное значение — **0**. Нужно ознакомиться с дополнительной информацией о фильмах с этим значением в столбце.
# * Максимальное значение **400 000 000** — похоже на выброс.

# %% [markdown]
# Построим диаграмму размаха, чтобы проверить столбец на наличие выбросов и аномальных значений:

# %%
# построим диаграмму размаха по столбцу 
mkrf.boxplot(column='nonrefundable_support')

# обозначим название диаграммы, параметром pad настроим высоту заголовка
# назовём ось 'y'
plt.title('Объём невозвратных средств государственной поддержки', pad=20)
plt.ylabel('Государственная поддержка в ₽')

# выведем на экран
plt.show()

# %% [markdown]
# * Выбросы достигают отметки около `250 000 000 рублей`. Видны отдельные особенно крупные значения — `300 000 000` и `400 000 000 рублей`.
# * Можно заметить выброс у нижнего уса на отметке **0**.

# %% [markdown]
# Посмотрим, сколько фильмов со значением **0** присутствует в столбце и ознакомимся с дополнительной информацией:

# %%
# вызовем функцию и отфильтруем значения
filtered_data(mkrf, 'nonrefundable_support', 0, 0)
# Out:
#                                    title  pu_number           show_start_date  \
# 2532                              бармен  111009615 2015-05-26 12:00:00+00:00
# 2683                          дабл трабл  111009215 2015-05-18 12:00:00+00:00
# 2733         неуловимые: последний герой  111017415 2015-09-30 12:00:00+00:00
# 3042                  крякнутые каникулы  114003615 2015-12-22 12:00:00+00:00
# 3224              кухня. последняя битва  111001517 2017-03-22 12:00:00+00:00
# 5659     три богатыря и принцесса египта  114003317 2017-12-21 12:00:00+00:00
# 6472  три богатыря и наследница престола  114008818 2018-12-15 12:00:00+00:00
# 6627                             рассвет  111000419 2019-01-31 12:00:00+00:00
# 7466         иван царевич и серый волк 4  114005019 2019-12-20 12:00:00+00:00
#
#                 type                                        film_studio  \
# 2532  Художественный          ао "вайт медиа", ооо "арт пикчерз студия"
# ...

# %% [markdown]
# * Найдено 9 фильмов со значением **0** в столбце.
# * Фильм `'Бармен'` с номером прокатного удостоверения **111009615** получил возвратные средства государственной поддержки — `20 000 000`. При этом он не получил невозвратные средства и бюджет составил **0**. Запись выглядит неправдоподобно, так как фильмы, которые получили финансирование от государственных организаций имеют определённый бюджет.
# * Остальные фильмы из выборки также получили возвратные средства, но у них бюджет заполнен, поэтому их данные выглядят правдоподобнее. В их случае значение 0 в столбце `nonrefundable_support` не кажется аномалией.

# %% [markdown]
# Признаем фильм `Бармен` аномалией и удалим запись из таблицы на этапе фильтрации.

# %% [markdown]
# Рассчитаем верхнюю границу нормального размаха:

# %%
# вызовем функцию и рассчитаем верхнюю границу выбросов
emission_limit(mkrf, 'nonrefundable_support')
# Out:
# 'Верхняя граница выбросов = 63437500.00'

# %% [markdown]
# Отфильтруем значения в столбце:

# %%
# отфильтруем строки датафрейма, у которых значение в столбце выше 63_437_500
# оставим строки с NaN в столбце с помощью isna()
good_mkrf = good_mkrf[(good_mkrf['nonrefundable_support'] <= 63437500) | good_mkrf['refundable_support'].isna()]

# исключим аномалию со значением 0 в бюджете
good_mkrf = good_mkrf[good_mkrf['pu_number'] != 111009615]

# проверим результат
good_mkrf['nonrefundable_support'].sort_values(ascending=False)
# Out:
# 5708    60000000
# 5804    60000000
# 7171    60000000
# 5852    60000000
# 2537    60000000
#           ...
# 7481        <NA>
# 7482        <NA>
# 7483        <NA>
# 7484        <NA>
# 7485        <NA>
# Name: nonrefundable_support, Length: 7415, dtype: Int64

# %% [markdown]
# Cравним результат предобработки, наложим гистограмму датафрейма до фильтрации — `mkrf` на гистограмму очищенных данных в `good_mkrf`:

# %%
# построим гистограмму на основе исходных данных
ax_2 = mkrf.plot(
    kind='hist',
    y='nonrefundable_support',
    histtype='step',
    range=(0, 400_000_000),
    bins=100,
    linewidth=5,
    alpha=0.7,
    label='raw',
)

# наложим на гистограмму после предобработки данных
good_mkrf.plot(
    kind='hist',
    y='nonrefundable_support',
    histtype='step',
    range=(0, 400_000_000),
    bins=100,
    linewidth=4,
    alpha=0.7,
    label='filtered',
    ax=ax_2,
    grid=True,
    legend=True,
)

# дадим название графику и осям
ax_2.set_title('Объём невозвратных средств государственной поддержки')
ax_2.set_xlabel('Государственная поддержка в ₽')
ax_2.set_ylabel('Количество фильмов')
# Out:
# Text(0, 0.5, 'Количество фильмов')

# %% [markdown]
# **Выводы:**
#
# * Удалили строку с аномальным значением из датафрейма `good_mkrf`.
# * Отфильтровали значения выше `63 437 500 рублей` по верхней границе нормального размаха.
# * В результате фильтрации исчез длинный хвост, распределение стало более концентрированным.

# %% [markdown]
# #### Изучение столбца 'budget'

# %% [markdown]
# Ознакомимся с гистограммой по столбцу с общим бюджетом фильма — `budget`:

# %%
# построим гистограмму с 50 корзинами
mkrf['budget'].hist(edgecolor='black', bins=50)

# обозначим название графика 
# назовём оси 'y' и 'x'
plt.title('Общий бюджет фильма')
plt.ylabel('Количество фильмов')
plt.xlabel('Денежные средства в ₽')

# выведем на экран
plt.show()

# %% [markdown]
# * На гистограмме видно два пика, большая часть данных сконцентрирована у минимальных значений.
# * Заметен небольшой хвост примерно до отметки в `700 000 000 рублей`. Далее — отдельные крупные значения около `1 000 000 000` и `2 000 000 000`.

# %% [markdown]
# Дополним гистограмму числовым описанием данных:

# %%
# выведем числовое описание данных столбца
mkrf['budget'].describe()
# Out:
# count    3.320000e+02
# mean     1.272297e+08
# std      1.885883e+08
# min      0.000000e+00
# 25%      4.200000e+07
# 50%      6.864992e+07
# 75%      1.419853e+08
# max      2.305074e+09
# Name: budget, dtype: float64

# %% [markdown]
# * Медиана выше среднего, а стандартное отклонение составляет **1.8**. Возможно, в столбце есть небольшие аномалии или выбросы.
# * Минимальное значение составляет **0**. Следует проверить дополнительную информацию о фильмах с таким значением.
# * Максимальное значение выглядит подозрительно — более `2 300 000 000 рублей`.
#
# Проверим данные в столбце на наличие выбросов, построим диаграмму размаха:

# %%
# построим диаграмму размаха по столбцу 
mkrf.boxplot(column='budget')

# обозначим название диаграммы, параметром pad настроим высоту заголовка
# назовём ось 'y'
# проставим метки на оси 'y' с шагом 100 000 000
plt.title('Общий бюджет фильма', pad=20)
plt.ylabel('Денежные средства в ₽')
plt.yticks(range(0, 2_305_074_303, 100_000_000))

# выведем на экран
plt.show()

# %% [markdown]
# * Выбросы достигают отметки в `1 000 000 000 рублей`.
# * Видно выброс, одно особенно крупное значение — `2 305 074 303 рублей`.

# %% [markdown]
# Посмотрим дополнительную информацию о фильмах с бюджетом **0**:

# %%
filtered_data(good_mkrf, 'budget', 0, 0)
# Out:
#                        title  pu_number           show_start_date  \
# 2053                     14+  111023614 2014-12-19 12:00:00+00:00
# 2684          тряпичный союз  111010215 2015-06-08 12:00:00+00:00
# 2788      срочно выйду замуж  111017115 2015-09-30 12:00:00+00:00
# 2874         помню не помню!  111004916 2016-03-01 12:00:00+00:00
# 3047  любовь с ограничениями  111008216 2016-04-29 12:00:00+00:00
# 3675                чудо-юдо  114001817 2017-06-27 12:00:00+00:00
# 3739                    мифы  111004317 2017-06-07 12:00:00+00:00
# 5673                   селфи  111012117 2018-02-01 12:00:00+00:00
# 5806              два хвоста  114001018 2018-05-31 12:00:00+00:00
#
#                 type                                        film_studio  \
# 2053  Художественный                         ооо киностудия  "сентябрь"
# 2684  Художественный                      ооо "кинокомпания "коктебель"
# 2788  Художественный          ао "вайт медиа", ооо "арт пикчерз студия"
# ...

# %% [markdown]
# * Найдено 17 фильмов с **нулевым** значением в столбце `budget`. При этом такие фильмы получили либо возвратные средства государственной поддержки, либо невозвратные. Указан источник финансирования.
#
# Можно предположить, что данные в столбце остались незаполнены в результате ошибки. Удалим такие фильмы из датафрейма, чтобы избежать некорректных результатов в ходе дальнейших расчётов.

# %% [markdown]
# Посмотрим дополнительную информацию о фильмах с бюджетом в диапазоне от `2 000 000 000` до `2 500 000 000 рублей`:

# %%
filtered_data(mkrf, 'budget', 2_000_000_000, 2_500_000_000)
# Out:
#                      title  pu_number           show_start_date  \
# 7114  тайна печати дракона  111012819 2019-09-12 12:00:00+00:00
#
#                 type                                        film_studio  \
# 7114  Художественный  ооо "кинокомпания "ств"; ооо "рфг корп"; ооо "...
#
#      production_country     director                producer  \
# 7114       Россия-Китай  О.Степченко  С.Сельянов, А.Петрухин
#
#                     age_restriction  refundable_support  \
# 7114  «6+» - для детей старше 6 лет           180000000
#
#       nonrefundable_support      budget financing_source  ratings  \
# 7114               90000000  2305074303        Фонд кино      5.8
#
#                    genres  box_office
# 7114  приключения,фэнтези   333597060

# %% [markdown]
# * Найден 1 художественный фильм — `Тайна печати дракона` от 2019.09.12. Фильм получил как возвратные — `180 000 000`, так и невозвратные средства поддержки — `90 000 000`. Бюджет картины составляет `2 305 074 303 рублей`.

# %% [markdown]
# Рассчитаем окупаемость фильма:

# %%
# сохраним в переменную film выбранную строку
film = mkrf[mkrf['pu_number'] == 111012819]

# сохраним общий бюджет фильма 
full_budget = film['budget'].sum()

# сохраним сборы фильма
box_office_movie = film['box_office'].sum()

# рассчитаем окупаемость 
payback = box_office_movie / full_budget

# округлим результат до 2 знаков после запятой и выведем на экран
print(round(payback * 100, 1), '%')
# Out:
# 14.5 %

# %% [markdown]
# Окупаемость фильма составляет всего 14.5 %, что говорит о неудаче фильма в прокате.
#
# Крупное значение в столбце можно назвать реалистичным, однако оно редкое и может смещать среднее вверх в ходе анализа, поэтому признаем его выбросом.

# %% [markdown]
# Рассчитаем верхнюю границу выбросов наиболее точно:

# %%
# вызовем функцию и рассчитаем верхнюю границу нормального размаха
emission_limit(mkrf, 'budget')
# Out:
# 'Верхняя граница выбросов = 291963298.75'

# %% [markdown]
# Отфильтруем данные в столбце:

# %%
# # отфильтруем строки датафрейма
# оставим строки с NaN в столбце с помощью isna()
# удалим строки со значением 0 в столбце budget
good_mkrf = good_mkrf[
    ((good_mkrf['budget'] <= 291963298.75) & (good_mkrf['budget'] != 0)) | 
    (good_mkrf['budget'].isna())
]

# проверим результат
good_mkrf['budget'].sort_values(ascending=False)
# Out:
# 3352    287802711
# 2005    252489571
# 3321    222513841
# 5516    219398491
# 3142    215860000
#           ...
# 7481         <NA>
# 7482         <NA>
# 7483         <NA>
# 7484         <NA>
# 7485         <NA>
# Name: budget, Length: 7400, dtype: Int64

# %% [markdown]
# Cравним результат предобработки, наложим гистограмму датафрейма до фильтрации — `mkrf` на гистограмму очищенных данных в `good_mkrf`:

# %%
# построим гистограммы на основе исходных данных
ax_3 = mkrf.plot(
    kind='hist',
    y='budget',
    histtype='step',
    range=(0, 500_000_000),
    bins=100,
    linewidth=5,
    alpha=0.7,
    label='raw',
)

# накладываем на гистограмму после предобработки данных
good_mkrf.plot(
    kind='hist',
    y='budget',
    histtype='step',
    range=(0, 500_000_000),
    bins=100,
    linewidth=3,
    alpha=0.8,
    label='filtered',
    ax=ax_3,
    grid=True,
    legend=True,
)

# дадим название графику и осям
ax_3.set_title('Общий бюджет')
ax_3.set_xlabel('Денежные средства в ₽')
ax_3.set_ylabel('Количество фильмов')
# Out:
# Text(0, 0.5, 'Количество фильмов')

# %% [markdown]
# **Выводы:**
#
# * Очистили датафрейм от строк со значением **0** в столбце `budget`, удалили выбросы в соответствии с верхней границей номального размаха.
# * В результате предобработки распределение стало более равномерным и концентрированным.

# %% [markdown]
# #### Изучение столбца 'box_office'

# %% [markdown]
# Ознакомимся с гистограммой по столбцу со сборами в рублях — `box_office`:

# %%
# построим гистограмму с 50 корзинами
mkrf['box_office'].hist(edgecolor='black', bins=50)

# обозначим название графика 
# назовём оси 'y' и 'x'
plt.title('Сборы в ₽')
plt.ylabel('Количество фильмов')
plt.xlabel('Денежные средства')

# выведем на экран
plt.show()

# %% [markdown]
# * На гистограмме заметен высокий пик у значения **0**, а также длинный узкий хвост почти до `2 000 000 000 рублей`.

# %% [markdown]
# Дополним гистограмму числовым описанием данных:

# %%
# выведем числовое описание данных
mkrf['box_office'].describe()
# Out:
# count    3.158000e+03
# mean     7.647870e+07
# std      2.403531e+08
# min      0.000000e+00
# 25%      8.623900e+04
# 50%      2.327988e+06
# 75%      2.397967e+07
# max      3.073569e+09
# Name: box_office, dtype: float64

# %% [markdown]
# * Среднее выше медианы на **5.3**, а стандартное отклонение составляет **2.4**. Значит, в данных есть выбросы.
# * Минимальное значение составляет **0**, а максимальное — **3 000 000 000**. Нужно проверить информацию о фильмах с такими значениями.

# %% [markdown]
# Проверим данные в столбце на наличие выбросов, построим диаграмму размаха:

# %%
# построим диаграмму размаха по столбцу 
mkrf.boxplot(column='box_office')

# обозначим название диаграммы, параметром pad настроим высоту заголовка
# назовём ось 'y'
plt.title('Сборы в ₽', pad=20)
plt.ylabel('Денежные средства')

# выведем на экран
plt.show()

# %% [markdown]
# * Выбросы достигают приблизительной отметки в `2 200 000 000 рублей`. Видно несколько особенно крупных значений от `2 500 000 000` до `3 000 000 000 рублей`.

# %% [markdown]
# Ознакомимся с информацией о фильмах со значением **0** в столбце `box_office`:

# %%
filtered_data(mkrf, 'box_office', 0, 0)
# Out:
#                                                   title  pu_number  \
# 66                                         анна павлова  111011013
# 237                                            подранки  111007613
# 596                                       запах вереска  111003012
# 914      в тумане /по одноименной повести василя быкова  121027712
# 932                                     письмо для момо  124002912
# 933                                        летние войны  124002812
# 976                                        гарегин нжде  131000213
# 1126                                            марафон  111006712
# 1387   экзамен для двоих /по роману джин ханфф корелитц  121014613
# 1559  последняя любовь мистера моргана /по роману фр...  121002614
# 1772                                  весёлые ребята ;)  111002414
# 1782                          анжелика, маркиза ангелов  121031913
# 1978                                    люблю твою жену  121013014
# ...

# %% [markdown]
# * Найдено 24 фильма, из которых 22 — художественные и 2 — анимационные.
#
# Рассчитаем средний рейтинг таких фильмов:

# %%
# отфильтруем строки со значением 0 в столбце box_office и посчитаем среднее
# округлим значение до 1 знака после запятой
mkrf[mkrf['box_office'] == 0 ]['ratings'].mean().round(1)
# Out:
# 6.7

# %% [markdown]
# Средний рейтинг фильмов составляет **6.7**. Среди жанров преобладает драма. У всех фильмов отсутствует государственная поддержка. Можно предположить, что источниками финансирования являются коммерческие организации.
#
# Отсутствие данных о сборах и наличие рейтинга можно объяснить несколькими факторами. Например, эти фильмы могли быть выпущены на стриминговых площадках или показаны на кинофестивалях. Также возможно, что фильмы были выпущены за рубежом — например, в Японии или США, и информация о сборах не была занесена в эту базу данных.

# %% [markdown]
# Хотя можно объяснить происхождение нулевых значений в столбце со сборами фильмов, мы отфильтруем такие строки из датафрейма для более корректных расчётов и результатов исследования.

# %% [markdown]
# Ознакомимся с информацией о фильмах со сборами в диапазоне `от 2 000 000 000 до 3 000 000 000 рублей`:

# %%
filtered_data(mkrf, 'box_office', 2_000_000_000, 3_000_000_000)
# Out:
#                                                   title  pu_number  \
# 2859                                         зверополис  124000316
# 3488  пираты карибского моря: мертвецы не рассказыва...  121009217
# 5653                                     движение вверх  111011817
# 6549                                               т-34  111024918
# 6820                                    мстители: финал  121005519
#
#                show_start_date            type  \
# 2859 2016-02-15 12:00:00+00:00    Анимационный
# 3488 2017-05-17 12:00:00+00:00  Художественный
# 5653 2017-12-21 12:00:00+00:00  Художественный
# 6549 2018-12-21 12:00:00+00:00  Художественный
# 6820 2019-04-29 12:00:00+00:00  Художественный
#
#                                             film_studio production_country  \
# 2859  уолт дисней анимейшн студиоз, уолт дисней пикчерз                США
# 3488  джерри брукхайэмер фильмз, уолт дисней пикчерз...                США
# ...

# %% [markdown]
# * В таблице найдёно **5** фильмов: **3** из них было снято в США, **2** — в России.
#
# Дополнительная информация выглядит правдоподобно, но в датафрейме мало записей с такими крупными сборами. Поэтому мы отфильтруем их для более корректного анализа.

# %% [markdown]
# Рассчитаем верхнюю границу нормального размаха:

# %%
emission_limit(mkrf, 'box_office')
# Out:
# 'Верхняя граница выбросов = 59819819.62'

# %% [markdown]
# Отфильтруем данные:

# %%
# отфильтруем строки датафрейма, у которых значение в столбце выше 59_819_819
# оставим строки с NaN в столбце с помощью isna()
# отфильтруем строки с 0 в box_office
good_mkrf = good_mkrf[
    ((good_mkrf['box_office'] <= 59_819_819) & (good_mkrf['box_office'] != 0)) | 
    (good_mkrf['box_office'].isna())
]

# проверим результат
good_mkrf['box_office'].sort_values(ascending=False)
# Out:
# 2164    59524891
# 6433    59431246
# 6434    59242029
# 7008    58778318
# 7058    58351843
#           ...
# 7481        <NA>
# 7482        <NA>
# 7483        <NA>
# 7484        <NA>
# 7485        <NA>
# Name: box_office, Length: 6889, dtype: Int64

# %% [markdown]
# Cравним результат предобработки, наложим гистограмму датафрейма до фильтрации — `mkrf` на гистограмму очищенных данных в `good_mkrf`:

# %%
# построим гистограммы на основе исходных данных
ax_4 = mkrf.plot(
    kind='hist',
    y='box_office',
    histtype='step',
    range=(0, 2_000_000_000),
    bins=100,
    linewidth=5,
    alpha=0.7,
    label='raw',
)

# накладываем на гистограмму после предобработки данных
good_mkrf.plot(
    kind='hist',
    y='box_office',
    histtype='step',
    range=(0, 2_000_000_000),
    bins=100,
    linewidth=5,
    alpha=0.7,
    label='filtered',
    ax=ax_4,
    grid=True,
    legend=True,
)

# дадим название графику и осям
ax_4.set_title('Сборы в ₽')
ax_4.set_ylabel('Количество фильмов')
ax_4.set_xlabel('Денежные средства')
# Out:
# Text(0.5, 0, 'Денежные средства')

# %% [markdown]
# **Выводы:**
#
# * Отфильтровали нулевые значения в столбце `box_office`, а также выбросы по верхней границе нормального размаха.
# * Распределение на гистограмме выглядит более концентрировано, убрали длинный хвост с особенно крупными значениями.

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# Создадим столбец с информацией о годе проката. Выделим год из даты премьеры фильма:

# %%
# отключим предупреждение SettingWithCopyWarning, так как good_mkrf это уже копия исходного mkrf
pd.options.mode.chained_assignment = None

# выделим год из даты с помощью dt.year
good_mkrf['release_year'] = good_mkrf['show_start_date'].dt.year

# проверим результат
good_mkrf.head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                США
# 1                              киностудия "мосфильм"               СССР
# 2  юниверсал пикчерз, кикстарт продакшнз, марк пл...                США
# 3  юниверсал пикчерз, кикстарт продакшнз, марк пл...                США
# 4  юниверсал пикчерз, кикстарт продакшнз, марк пл...                США
#
# ...

# %% [markdown]
# Создадим два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров.

# %%
# напишем функцию для создания 2 новых столбцов 
# разобьём строки на списки элементов в выбранных столбцах, выберем первый элемент  
# вернём Series, чтобы создать 2 колонки сразу
def main_genre_and_director(row):
    main_director = row['director'].split(',')[0] 
    main_genre = row['genres'].split(',')[0]
    return pd.Series([main_director, main_genre], index=['main_director', 'main_genre'])

# вызовем функцию с помощью apply() 
good_mkrf[['main_director', 'main_genre']] = good_mkrf.apply(main_genre_and_director, axis=1)

# проверим результат
good_mkrf.tail(40)
# Out:
#                                                   title  pu_number  \
# 7440                            миллион мелких осколков  121036519
# 7441                                            21 мост  121036719
# 7442                             рожденный после смерти  121036819
# 7443                                     импрессионисты  126007519
# 7444                      микеланджело: любовь и смерть  126007619
# 7445                                вальгалла: рагнарек  121035619
# 7446                                   выпьем за любовь  121036319
# 7447        "фееринки". серия "фантик спешит на помощь"  124010019
# 7448                                              код 8  121036419
# 7449       щенячий патруль: мегащенки и отважные птенцы  124010119
# 7450                                      в тихом омуте  121036919
# 7451                             дорога в бесконечность  113001519
# 7452                                     убить человека  111021519
# ...

# %% [markdown]
# Добавим столбец с долей государственной поддержки от общего бюджета фильма:

# %%
# сложим возвратные и невозвратные средства гос. поддержки
# разделим сумму на бюджет
# округлим результат и сохраним в столбец state_support_share
good_mkrf['state_support_share_%'] = (
    (good_mkrf['refundable_support'] + good_mkrf['nonrefundable_support']) 
    / good_mkrf['budget'] * 100).astype(float).round(1)

# проверим результат
good_mkrf.tail(10)
# Out:
#                                              title  pu_number  \
# 7475                                          папа  111022919
# 7476                                    я свободен  111023019
# 7477                                      тридцать  121038419
# 7479                                        эколав  111023219
# 7480               акрам хан: родом из карри хауса  126007919
# 7481     сад художника: американский импрессионизм  126008019
# 7482                               звериная ярость  121037819
# 7483     щенячий патруль: скорей спешим на помощь!  124010819
# 7484      машины песенки. серия "испанские мотивы"  124010619
# 7485  машины песенки. серия "когда цветут кактусы"  124010719
#
#                show_start_date            type  \
# 7475 2019-12-24 12:00:00+00:00  Художественный
# 7476 2019-12-26 12:00:00+00:00  Художественный
# 7477 2019-12-26 12:00:00+00:00  Художественный
# 7479 2019-12-26 12:00:00+00:00  Художественный
# ...

# %% [markdown]
# Изменим в датафрейме столбец `age_restriction`. Сформулируем категории более кратко, для удобного обращения к элементам столбца в ходе анализа:
#
# - «0+» - для любой зрительской аудитории — `0 - 12 лет`
# - «6+» - для детей старше 6 лет — `6 - 12 лет`
# - «12+» - для детей старше 12 лет — `12 - 16 лет`
# - «16+» - для детей старше 16 лет — `16 - 18 лет`
# - «18+» - запрещено для детей — `от 18 лет`

# %%
def age_restriction(row):
    if '0' in row:
        return '0 - 6 лет'
    elif '6' in row:
        return '6 - 12 лет'
    elif '12' in row:
        return '12 - 16 лет'
    elif '16' in row:
        return '16 - 18 лет'
    elif '18' in row:
        return 'от 18 лет'

#print(age_restriction('12'))

# вызовем функцию с помощью apply
good_mkrf['age_restriction'] = good_mkrf['age_restriction'].apply(age_restriction)

# проверим результат
good_mkrf.head(10)
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
# 5     остановился поезд  111013816 2016-09-13 12:00:00+00:00  Художественный
# 6       любовь и голуби  111007013 2013-10-18 12:00:00+00:00  Художественный
# 7     любовь и сигареты  221074614 2014-12-29 12:00:00+00:00  Художественный
# 8     отпетые мошенники  121011416 2016-05-05 12:00:00+00:00  Художественный
# 9   отпуск за свой счет  111019114 2014-12-01 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# ...

# %% [markdown]
# **Выводы:**
#
# На этапе предобработки были обнаружены следующие проблемы в данных:
#
# * Некорректное наименование столбца.
# * Некорректные типы данных.
# * Пропущенные значения.
# * Неявные дубликаты в столбцах с категориальными переменными
# * Аномалии и выбросы в столбцах с количественными переменными
#
# Изменили регистр в названии столбца: `puNumber` на `pu_number`.
#
# Привели столбец `show_start_date` со строковым типом данных к типу `datetime`, преобразовали строковый тип данных в столбце `ratings` в `float`, привели к целочисленному типу значения в столбцах `refundable_support`, `nonrefundable_support`, `budget`, `box_office`.
#
# Заполнили пропуски значением неизвестно в следующих столбцах с категориальными переменными: `genres`, `producer`, `film_studio`, `director`, `production_country`, `financing_source`. Удалили строку с пропущенным значением в столбце `pu_number`.
#
# Обработали неявные дубликаты в столбцах: `title`, `type`, `film_studio`, `production_country`, `director`, `producer`, `age_restriction`, `financing_source`, `genres`.
#
# Очистили от аномалий столбцы с числами: `refundable_support`, `nonrefundable_support`, `budget` и `box_office`.
#
# Создали новые столбцы в датафрейме: `с информацией о годе проката`, `с именем и фамилией главного режиссёра и основным жанром фильма`, `с долей государственной поддержки от общего бюджета фильма`. Изменили в датафрейме столбец `age_restriction`, cформулировали категории более кратко.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ взаимосвязи между годом и выходом фильма в прокат

# %% [markdown]
# * Посмотрим, сколько фильмов выходило в прокат каждый год.
# * Посчитаем, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.
# * Проанализируем, как эта доля менялась по годам.
# * Сделаем вывод о том, какой период полнее всего представлен в данных.

# %% [markdown]
# Посмотрим, сколько фильмов выходило в прокат каждый год, независимо от наличия данных в столбце `box_office`:

# %%
# построим сводную таблицу
# сгруппируем количество строк с названиями фильмов по каждому году премьеры фильма
release_title_count = good_mkrf.pivot_table(index='release_year', values='title', aggfunc='count')

# построим столбчатую диаграмму методом plot
release_title_count.plot(kind='bar', edgecolor='black')

# обозначим заголовок
# назовём оси 'x' и 'y'
# повернём подписи на оси 'x'
plt.title('Прокат фильмов по годам')
plt.xlabel('Год')
plt.ylabel('Количество фильмов')
plt.xticks(rotation=1)

# выведем диаграмму на экран
plt.show()

# %% [markdown]
# Согласно диаграмме без учёта данных в столбце с кассовыми сборами:
#
# * Самое большое количество фильмов вышло в 2010 году — около 1000.
# * Самое маленькое количество фильмов вышло в 2017 году — около 400.

# %% [markdown]
# Предположим, что фильм точно вышел в прокат, если заполнен столбец со сборами — `box_office`. Построим столбчатую диаграмму, чтобы наглядно изобразить количество фильмов в прокате за каждый год:

# %%
# построим сводную таблицу
# сгруппируем количество строк со сборами в рублях по каждому году премьеры фильма
release_box_office_count = good_mkrf.pivot_table(index='release_year', values='box_office', aggfunc='count')

# построим столбчатую диаграмму методом plot
release_box_office_count.plot(kind='bar', edgecolor='black')

# обозначим заголовок диаграммы
# назовём оси 'x' и 'y'
# повернём подписи на оси 'x'
plt.title('Прокат фильмов по годам')
plt.ylabel('Количество фильмов')
plt.xlabel('Год')
plt.xticks(rotation=1)

# выведем диаграмму на экран
plt.show()

# %% [markdown]
# Согласно диаграмме с заполненными данными в столбце с кассовыми сборами:
#
# * В 2010 году было зафиксировано наименьшее количество фильмов, вышедших в прокат, — 100 картин.
# * До 2012 года наблюдается постепенный рост числа релизов.
# * После 2012 года темпы увеличения количества фильмов становятся более выраженными. В 2016 году их число достигает 400, после чего в 2017 году происходит резкое снижение до примерно 250.
# * Максимальное количество фильмов, вышедших в прокат, зафиксировано в 2019 году — около 450.

# %% [markdown]
# Рассчитаем конверсию и посмотрим, какую долю составляют фильмы с указанной информацией о сборах от общего количества фильмов:

# %%
# разделим количество фильмов с данными в box_office на общее количество фильмов 
box_office_share = good_mkrf['box_office'].count() / good_mkrf['title'].count()

# выведем результат на экран
print('Доля фильмов с указанной информацией о прокате в кинотеатрах:', (box_office_share*100).round(1), '%')
# Out:
# Доля фильмов с указанной информацией о прокате в кинотеатрах: 37.2 %

# %% [markdown]
# Рассчитаем конверсию фильмов со сборами в зависимости от года:

# %%
# c помощью pivot_table найдём количество фильмов со сборами в зависимости от года
# найдём общее количество фильмов  в зависимости от года
box_office_title_count = good_mkrf.pivot_table(
    index='release_year',
    values=['box_office', 'title'],
    aggfunc={'box_office':'count', 'title':'count'}
)

# рассчитаем долю, умножим на 100 и округлим результат до 1 знака после запятой
movie_release_year_share = ((box_office_title_count['box_office'] / box_office_title_count['title'])*100).round(1)

# проверим результат
movie_release_year_share
# Out:
# release_year
# 2010    10.3
# 2011    17.5
# 2012    20.9
# 2013    28.5
# 2014    32.3
# 2015    59.9
# 2016    58.2
# 2017    63.9
# 2018    45.8
# 2019    51.5
# dtype: float64

# %% [markdown]
# Представим информацию более наглядно, построим график изменения доли фильмов со сборами для каждого года:

# %%
# построим график с помощью метода plot()
movie_release_year_share_plot = movie_release_year_share.plot(grid=True, figsize=(12, 6), style='o-')

# добавим все года на ось абсцисс 
movie_release_year_share_plot.set_xticks(movie_release_year_share.index)

# добавим заголовок, название осей 'y' и 'x'
# настроим их размер с помощью fontsize
movie_release_year_share_plot.set_title('Изменение доли фильмов с данными о сборах по годам', fontsize=17)
movie_release_year_share_plot.set_ylabel('Конверсия в %', fontsize=14)
movie_release_year_share_plot.set_xlabel('Год', fontsize=14)

# установим более высокое разрешение 
plt.gcf().set_dpi(150)

# %% [markdown]
# * На графике видно, что полнее всего представлен в данных период `с 2015 до 2017 года`. Доля достигла максимального значения в этот отрезок времени, сначала **59.9 %** `в 2015`, затем — **63.9 %** `в 2017 году`.
# * `До 2018 года` доля стремительно уменьшалась и достигла значения — **45.8 %**.

# %% [markdown]
# **Выводы:**
#
# * `В 2010 году` в прокат вышло меньше всего фильмов — **100**.
# * `В 2019 году` вышло максимальное количество фильмов — около **450**.
# * Согласно расчётам, доля фильмов с указанной информацией о прокате в кинотеатрах составляет **37.2 %** от общего количества картин.
# * Полнее всего представлен в данных период `с 2015 до 2017 года`. Максимальное значение составила доля `в 2017 году` — **63.9 %.**

# %% [markdown]
# ### Анализ изменения динамики проката по годам

# %% [markdown]
# * Посмотрим на минимальную и максимальную сумма сборов в каждом году.
# * Посмотрим, в каком году сумма сборов была минимальной и максимальной.
# * Посчитаем среднюю и медианную сумму сборов для каждого года.

# %%
# с помощью сводной таблицы выведем максимальную и минимальную сумму в каждом году
min_max_release_year = good_mkrf.pivot_table(index='release_year', values='box_office', aggfunc=['min', 'max'])

# проверим результат
min_max_release_year
# Out:
#                     min        max
#              box_office box_office
# release_year
# 2010                 75    1446400
# 2011                125   11618085
# 2012                 80    2311220
# 2013                 40    4321638
# 2014                 50   50987664
# 2015                100   59524891
# 2016                200   57783155
# 2017               7900   57293208
# 2018              41225   59431246
# 2019               4398   58778318

# %% [markdown]
# * Минимальная сумма сборов зафиксирована `в 2013 году` - всего лишь `40 рублей`.
# * Максимальная сумма сборов — `в 2015 году`, `59 524 891 рублей`.

# %% [markdown]
# Для большей наглядности построим линейный график:

# %%
# импортируем класс MaxNLocator для управления количеством меток на оси
from matplotlib.ticker import MaxNLocator

# создадим две оси на одном графике с помощью plt.subplots()
# создадим два графика, расположенных вертикально
# зададим размер фигуры 
# сделаем ось 'x' общей для обоих графиков
fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

# построим график с минимальными значениями
axes[0].plot(min_max_release_year.index, min_max_release_year['min'], marker='o', linestyle='-', color='purple')
axes[0].set_title('Минимальная сумма')
axes[0].set_ylabel('Сборы в ₽')
axes[0].yaxis.set_major_locator(MaxNLocator(nbins=10))
axes[0].grid(True)

# построим график с максимальными значениями
axes[1].plot(min_max_release_year.index, min_max_release_year['max'], marker='o', linestyle='-', color='red')
axes[1].set_title('Максимальная сумма')
axes[1].set_ylabel('Сборы в ₽')
axes[1].set_xlabel('Год')
axes[1].yaxis.set_major_locator(MaxNLocator(nbins=10))
axes[1].grid(True)

# установим более высокое разрешение
plt.gcf().set_dpi(150)

# %% [markdown]
# * В `2017 году` виден занчительный рост минимальной суммы кассовых сборов. В период `с 2017 до 2018 года` произошёл резкий подъём с `7 900 до 41 225 рублей` и резкий спад `с 2018 до 2019 года` — сумма уменьшилась практически в 9 раз, `до 4 398 рублей`.
# * В период `с 2010 до 2011 года` наблюдается рост максимальной суммы сборов `с 1 446 400 до 11 618 085 рублей`. Заметен резкий скачок вверх в период `с 2013 до 2014 года - с 4 321 638 до 50 987 664 рублей`. Далее сумма остаётся высокой на стабильном уровне без сильных изменений, варьируется `от 57 293 208 до 59 524 891 рублей`.

# %% [markdown]
# Рассчитаем среднюю сумму сборов для каждого года:

# %%
# рассчитаем среднюю сумму с помощью pivot_table()
mean_box_office = good_mkrf.pivot_table(index='release_year', values='box_office')

# выведем результат на экран
mean_box_office
# Out:
#                    box_office
# release_year
# 2010             24046.079208
# 2011            129383.165138
# 2012             56548.154472
# 2013             55295.932584
# 2014           1865091.694444
# 2015           8828424.198324
# 2016           7578160.194103
# 2017          10216785.328244
# 2018           9771050.289773
# 2019           8600544.625592

# %% [markdown]
# Рассчитаем медианную сумму сборов для каждого года:

# %%
# рассчитаем медианную сумму с помощью pivot_table
median_box_office = good_mkrf.pivot_table(index='release_year', values='box_office', aggfunc='median')

# проверим результат
median_box_office
# Out:
#               box_office
# release_year
# 2010              1710.0
# 2011              3000.0
# 2012              6220.0
# 2013              3565.0
# 2014             16232.5
# 2015           2238500.5
# 2016           1735813.0
# 2017           4731709.0
# 2018           4601725.5
# 2019           2819216.0

# %% [markdown]
# Для более комфортного восприятия построим линейные графики и сравним результат расчётов:

# %%
# создадим две оси на одном графике с помощью plt.subplots()
# создадим два графика, расположенных вертикально
# зададим размер фигуры
# сделаем ось 'x' общей для обоих графиков
fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

# построим график для средней суммы сборов
axes[0].plot(mean_box_office, marker='o', linestyle='-', color='orange')
axes[0].set_title('Средняя сумма сборов для каждого года')
axes[0].set_ylabel('Сборы в ₽')
axes[0].yaxis.set_major_locator(MaxNLocator(nbins=10))
axes[0].grid(True)
     
# построим график для медианной суммы сборов
axes[1].plot(median_box_office, marker='o', linestyle='-', color='blue')
axes[1].set_title('Медианная сумма сборов для каждого года')
axes[1].set_xlabel('Год')
axes[1].set_ylabel('Сборы в ₽')
axes[1].yaxis.set_major_locator(MaxNLocator(nbins=10))
axes[1].grid(True)

# установим более высокое разрешение
plt.gcf().set_dpi(150)

# %% [markdown]
# * Средняя сумма сборов начала заметно расти в период `с 2013 до 2014 года`, далее виден резкий подъём `с 2014 по 2015 год` — **с 1 865 091 до 8 828 424 ₽**. `До 2016` года значение опустилось **до 7 578 160 ₽**, `в 2017` снова возросло и достигло максимума — **10 216 785**. Далее сумма плавно опустилась **до 8 600 544 ₽**.
#
# * В отличие от среднего значения, на графике с медианной суммой не наблюдается ощутимого роста в период `с 2013 до 2014 года`, однако виден резкий подъём с `с 2014 по 2015 год` — **с 16 232 до 2 238 500 ₽**. Далее значение аналогично опускается `до 2016 года`, но на меньшую сумму — **1 735 813 ₽**. В 2017 году максимальная сумма составила **4 731 709**. Виден резкий спад с 2018 по 2019 год — до **2 819 216 ₽**.
#
# Значения на двух графиках существенно отличаются друг от друга. Мы будем полагаться на результаты расчётов медианной суммы, так как медиана более устойчива к выбросам, чем среднее.

# %% [markdown]
# **Выводы:**
#
# * Минимальная сумма сборов — в 2013 году, 40 рублей.
# * Максимальная сумма сборов — в 2015 году, 59 524 891 рублей.
# * С 2010 по 2014 год наблюдается значительный рост максимальных сборов, после чего сумма стабилизируется, а минимальные сборы резко поднимаются в 2017–2018 годах, но в 2019 году падают почти в 9 раз.
# * Средняя и медианная суммы сборов показывают схожую динамику роста и спада, но отличие в 2013–2014 годах указывает на влияние выбросов. Также значительно отличается сумма сборов для каждого года. Медиана более устойчива к выбросам и лучше отражает общий тренд.

# %% [markdown]
# ### Анализ взаимосвязи между возрастным ограничением и сборами фильмов в прокате

# %% [markdown]
# Определим, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год:
#
# * Посмотрим, фильмы с каким возрастным ограничением собрали больше всего денег в прокате.
# * Изучим, меняется ли картина в зависимости от года.

# %% [markdown]
# Посмотрим, фильмы для какой возрастной группы собрали больше всего денег в прокате независимо от года проката:

# %%
# построим сводную таблицу и рассчитаем сумму сборов для каждой возрастной группы
good_mkrf.pivot_table(index='age_restriction', values='box_office', aggfunc='sum').sort_values(by='box_office', ascending=False)
# Out:
#                  box_office
# age_restriction
# 6 - 12 лет       7336506871
# от 18 лет        7044488617
# 12 - 16 лет      1742118873
# 0 - 6 лет         370742616

# %% [markdown]
# * Независимо от года проката, самую большую сумму в прокате собрали фильмы с возрастным ограничением `6 - 12 лет` — **7 336 506 871**, а минимальную сумму `0 - 6 лет`— **370 742 616**.

# %% [markdown]
# Выберем строки в датафрейме с информацией о фильмах с годом проката — `от 2015 до 2019`:

# %%
# отфильтруем фильмы с годом проката от 2015 до 2019
release_year_query = good_mkrf.query('release_year >= 2015 and release_year <= 2019')

# проверим результат
release_year_query.head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                США
# 1                              киностудия "мосфильм"               СССР
# 2  юниверсал пикчерз, кикстарт продакшнз, марк пл...                США
# 3  юниверсал пикчерз, кикстарт продакшнз, марк пл...                США
# 4  юниверсал пикчерз, кикстарт продакшнз, марк пл...                США
#
# ...

# %% [markdown]
# Посмотрим, фильмы для какой возрастной группы собрали больше всего денег в прокате в период `с 2015 по 2019`:

# %%
# построим сводную таблицу для расчётов 
release_year_query.pivot_table(index=['age_restriction'], values='box_office', aggfunc='sum').sort_values(by='box_office', ascending=False)
# Out:
#                  box_office
# age_restriction
# 6 - 12 лет       7210039571
# от 18 лет        6885482394
# 12 - 16 лет      1606696451
# 0 - 6 лет         288305936

# %% [markdown]
# * В период `с 2015 по 2019` год больше всего денег собрали фильмы с ограничением `6 - 12 лет` — **7 210 039 571**, меньше всего `0 - 6 лет` — **288 305 936**.

# %% [markdown]
# Построим сводную таблицу, рассчитаем сумму сборов для каждого возрастного ограничения за каждый год в период `с 2015 по 2019`:

# %%
# построим сводную таблицу для расчётов и сохраним результат
age_restriction_year_box_office_sum = release_year_query.pivot_table(
    index=['age_restriction', 'release_year'],
    values='box_office',
    aggfunc='sum'
)

# проверим результат
age_restriction_year_box_office_sum.sort_values(by='box_office', ascending=False)
# Out:
#                               box_office
# age_restriction release_year
# от 18 лет       2019          1647660090
# 6 - 12 лет      2018          1607541792
# от 18 лет       2018          1603639398
# 6 - 12 лет      2019          1527089754
#                 2016          1485281226
#                 2015          1416988759
# от 18 лет       2015          1249389596
#                 2016          1194429190
#                 2017          1190364120
# 6 - 12 лет      2017          1173138040
# 12 - 16 лет     2019           436933922
#                 2015           364702212
#                 2016           319105955
#                 2017           290174852
#                 2018           195779510
# 0 - 6 лет       2015           129495296
#                 2016            85494828
#                 2018            32449002
#                 2017            23120744
#                 2019            17746066

# %% [markdown]
# * Наибольшие кассовые сборы зафиксированы у фильмов с рейтингом `от 18 лет` в `2019 году` — **1 647 660 090 ₽**.
# * Далее идут фильмы с категорией `6 - 12 лет` в `2018 году` с **1 607 541 792 ₽**.
# * Категория `12–16 лет` собрала значительно меньше денег. Максимальное значение в `2019 году` — **436 933 922 ₽**. При этом сумма постепенно снижалась `с 2015 по 2018 год`.
# * Фильмы для самой младшей аудитории `0–6 лет` имеют наименьшие сборы, с максимальным значением в `2015 году` **129 495 296 ₽** и резким падением в `2019 году` — до **17 746 066**.

# %% [markdown]
# Динамика кассовых сборов по годам в зависимости от рейтингов фильмов может быть связана с изменением предпочтений аудитории, маркетинговыми стратегиями и экономическими факторами, а также с популярностью жанров.

# %% [markdown]
# **Выводы:**
#
# * Возрастное ограничение фильмов влияет на кассовые сборы.
# * Наибольшие суммы в период с 2015 по 2019 год собрали картины для аудитории 6–12 лет.
# * Фильмы 18+ также показали высокие результаты, особенно в 2019 году, тогда как проекты для зрителей младше 6 лет стабильно приносили наименьшие доходы.
# * Динамика сборов может быть обусловлена изменением предпочтений зрителей, маркетинговыми стратегиями и общей ситуацией в индустрии кино.

# %% [markdown]
# ### Исследование фильмов с государственной поддержкой

# %% [markdown]
# * Посмотрим, сколько средств выделяют на поддержку кино.
# * Проверим, хорошо ли фильмы окупаются.

# %% [markdown]
# Выделим фильмы с государственной поддержкой в отдельный датафрейм:

# %%
# создадим датафрейм с гос.поддержкой с помощью query()
supported_good_mkrf = good_mkrf.query('refundable_support > 0 or nonrefundable_support > 0')

# проверим результат
supported_good_mkrf.head()
# Out:
#                                           title  pu_number  \
# 1281                              пока еще жива  111005313
# 1448                        бесславные придурки  111003314
# 1524                                      берцы  111004314
# 1792                                   братья ч  111004414
# 1854  тайна сухаревой башни. чародей равновесия  114000115
#
#                show_start_date            type  \
# 1281 2013-10-11 12:00:00+00:00  Художественный
# 1448 2014-03-28 12:00:00+00:00  Художественный
# 1524 2014-05-05 12:00:00+00:00  Художественный
# 1792 2014-04-23 12:00:00+00:00  Художественный
# 1854 2015-02-18 12:00:00+00:00    Анимационный
#
#                                             film_studio production_country  \
# 1281  ано содействия развитию кинематографии "ангел-...             Россия
# 1448                         ооо "компания "атк-студио"             Россия
# 1524                             ооо "студия "пассажир"             Россия
# ...

# %% [markdown]
# Посмотрим, сколько средств было выделено на поддержку кино в целом:

# %%
# сложим сумму возвратной и невозвратной поддержки
supported_good_mkrf['refundable_support'].sum() + supported_good_mkrf['nonrefundable_support'].sum()
# Out:
# 6196708450

# %% [markdown]
# Посмотрим, хорошо ли окупаются фильмы с государственной поддержкой:

# %%
# разделим сумму сборов на общую сумму гос. поддержки
# округлим результат
(supported_good_mkrf['box_office'].sum() / (supported_good_mkrf['refundable_support'].sum() + supported_good_mkrf['nonrefundable_support'].sum())).round(2)
# Out:
# 0.24

# %% [markdown]
# Согласно расчётам, сумма государственной поддержки кино превышает кассовые сборы, что указывает на низкую окупаемость таких фильмов.

# %% [markdown]
# Проверим, какие фильмы с государственной поддержкой окупаются лучше всего:

# %%
# создадим копию исходного датафрейма
supported_good_mkrf_copy = supported_good_mkrf.copy()

# рассчитаем окупаемость для каждого фильма и добавим новый столбец
supported_good_mkrf_copy['movie_payback'] = supported_good_mkrf_copy['box_office'] / (
                                            supported_good_mkrf_copy['refundable_support'] + 
                                            supported_good_mkrf_copy['nonrefundable_support'])
# проверим результат
supported_good_mkrf_copy.head()
# Out:
#                                           title  pu_number  \
# 1281                              пока еще жива  111005313
# 1448                        бесславные придурки  111003314
# 1524                                      берцы  111004314
# 1792                                   братья ч  111004414
# 1854  тайна сухаревой башни. чародей равновесия  114000115
#
#                show_start_date            type  \
# 1281 2013-10-11 12:00:00+00:00  Художественный
# 1448 2014-03-28 12:00:00+00:00  Художественный
# 1524 2014-05-05 12:00:00+00:00  Художественный
# 1792 2014-04-23 12:00:00+00:00  Художественный
# 1854 2015-02-18 12:00:00+00:00    Анимационный
#
#                                             film_studio production_country  \
# 1281  ано содействия развитию кинематографии "ангел-...             Россия
# 1448                         ооо "компания "атк-студио"             Россия
# 1524                             ооо "студия "пассажир"             Россия
# ...

# %% [markdown]
# Выведем информацию о 10 фильмах, которые окупаются лучше всего:

# %%
supported_good_mkrf_copy.head(10).sort_values(by='movie_payback', ascending=False)
# Out:
#                                           title  pu_number  \
# 1997       овечка долли была злая и рано умерла  111015214
# 1854  тайна сухаревой башни. чародей равновесия  114000115
# 2014                         дедушка моей мечты  111007714
# 1871                                две женщины  111013714
# 1991                                    смайлик  111008614
# 1281                              пока еще жива  111005313
# 1792                                   братья ч  111004414
# 1524                                      берцы  111004314
# 1912                                     ведьма  111002215
# 1448                        бесславные придурки  111003314
#
#                show_start_date            type  \
# 1997 2014-11-10 12:00:00+00:00  Художественный
# 1854 2015-02-18 12:00:00+00:00    Анимационный
# 2014 2014-07-22 12:00:00+00:00  Художественный
# 1871 2014-10-02 12:00:00+00:00  Художественный
# 1991 2014-08-08 12:00:00+00:00  Художественный
# ...

# %% [markdown]
# * Лидер по окупаемости — фильм `«Овечка Долли была злая и рано умерла»` с коэффициентом **1.74**, при бюджете **70,8 млн** и сборах **43,5 млн**.
# * На втором месте `«Тайна Сухаревой Башни. Чародей равновесия»`, окупаемость которого составила **0.60**.
# * Некоторые фильмы, такие как `«Дедушка моей мечты»` и `«Две женщины»`, показали наиболее низкие показатели окупаемости.
#
# Источником финансирования фильма-лидера является `Фонд кино`, у остальных 9 фильмов - `Министерство культуры`. Рейтинг фильмов варьируется с **6.1** до **8.1**.

# %% [markdown]
# **Выводы:**
#
# * Исследование показало, что общая сумма государственной поддержки кино составила более 6,19 млрд рублей, однако окупаемость фильмов с господдержкой оказалась низкой — в среднем 0,24 рубля на 1 рубль вложений.
# * Лидером по окупаемости стал фильм «Овечка Долли была злая и рано умерла» с коэффициентом 1.74, тогда как большинство фильмов, таких как «Дедушка моей мечты» и «Две женщины», имеют наиболее низкую окупаемость.
# * Основным источником финансирования большинства фильмов выступило Министерство культуры, а для лидера — Фонд кино.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе исследовательского анализа данных мы изучили столбцы с категориальными переменными и обнаружили неявные дубликаты. Также изучили столбцы с количественными переменными и установили наличие аномальных значений и выбросов. Обработали неявные дубликаты, устранили выбросы с помощью диаграммы размаха и межквартильного размаха.
#
# Выявили текущие тренды на рынке российского кинопроката:
#
# * `В 2010 году` было выпущено **100** фильмов, а `в 2019` — около **450**. Наибольшая доля фильмов с данными о прокате была в `2017 году` — **63.9%**.
#
#
# * Минимальные сборы были `в 2013 году` — **40** рублей, максимальные `в 2015 году` — **59,5** млн рублей. `После 2014 года` сборы стабилизировались, но `в 2019 году` минимальные сборы упали почти в **9 раз**. Медиана сборов менее подвержена выбросам.
#
#
# * Возрастное ограничение влияет на кассовые сборы. Фильмы для аудитории `6–12 лет` и `18+` были наиболее прибыльными, в то время как картины для зрителей младше приносили наименьшие доходы.
#
#
# * Общая государственная поддержка кино составила более **6,19** млрд рублей, но окупаемость фильмов с господдержкой низкая — **0,24** рубля на **1** рубль вложений. Лидером по окупаемости стал фильм жанра фантастика `"Овечка Долли была злая и рано умерла"`.
